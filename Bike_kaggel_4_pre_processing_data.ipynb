# %% [markdown]
# <a href="https://colab.research.google.com/github/jafuma0320/2024-Online-Bike-Availability-Prediction/blob/main/Bike_kaggel_4_pre_processing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install --upgrade holidays
# Out:
# Requirement already satisfied: holidays in /usr/local/lib/python3.10/dist-packages (0.51)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays) (1.16.0)

# %%
import pandas as pd
from collections import Counter
import datetime
import holidays

# %%
from google.colab import drive

# Mount the Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
result_df = pd.read_csv('/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/3 attempt/preprocessed_data_ctxs.csv')
result_df
# Out:
#          station_id    year  month   day  hour  percentage_docks_available  \
# 0               1.0  2020.0    1.0   1.0   3.0                    0.346296
# 1               1.0  2020.0    1.0   1.0   8.0                    0.235185
# 2               1.0  2020.0    1.0   1.0  13.0                    0.385185
# 3               1.0  2020.0    1.0   1.0  18.0                    0.177778
# 4               1.0  2020.0    1.0   1.0  23.0                    0.450000
# ...             ...     ...    ...   ...   ...                         ...
# 2641510       496.0  2023.0   12.0  31.0   3.0                    0.504630
# 2641511       496.0  2023.0   12.0  31.0   8.0                    0.388889
# 2641512       496.0  2023.0   12.0  31.0  13.0                    0.861111
# 2641513       496.0  2023.0   12.0  31.0  18.0                    0.666667
# 2641514       496.0  2023.0   12.0  31.0  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1
# 0        0.511111  0.492593  0.459259  0.394444
# 1        0.283333  0.364815  0.298148  0.233333
# 2        0.248148  0.262963  0.342593  0.337037
# 3        0.381481  0.335185  0.244444  0.211111
# 4        0.079630  0.209259  0.418519  0.492593
# ...           ...       ...       ...       ...
# 2641510  0.564815  0.518519  0.606481  0.523148
# 2641511  0.555556  0.537037  0.490741  0.435185
# 2641512  0.490741  0.412037  0.551282  0.646465
# 2641513  0.879630  0.819444  0.768519  0.699074
# 2641514  0.722222  0.643519  0.736111  0.731481
#
# [2641515 rows x 10 columns]

# %% [markdown]
# Converti a entero las columnas de la fecha

# %%
result_df['year'] = result_df['year'].astype(int)
result_df['month'] = result_df['month'].astype(int)
result_df['day'] = result_df['day'].astype(int)

# %%
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1
# 0        0.511111  0.492593  0.459259  0.394444
# 1        0.283333  0.364815  0.298148  0.233333
# 2        0.248148  0.262963  0.342593  0.337037
# 3        0.381481  0.335185  0.244444  0.211111
# 4        0.079630  0.209259  0.418519  0.492593
# ...           ...       ...       ...       ...
# 2641510  0.564815  0.518519  0.606481  0.523148
# 2641511  0.555556  0.537037  0.490741  0.435185
# 2641512  0.490741  0.412037  0.551282  0.646465
# 2641513  0.879630  0.819444  0.768519  0.699074
# 2641514  0.722222  0.643519  0.736111  0.731481
#
# [2641515 rows x 10 columns]

# %% [markdown]
# ## Tarea: Añadir una nueva columna con información sobre el weekday

# %% [markdown]
# Voy a probar primero en una muestra y luego si funciona lo aplico a toda la base.

# %%
year = result_df['year'][0]
month = result_df['month'][0]
day = result_df['day'][0]

# %%
date = datetime.date(year, month, day)
date
# Out:
# datetime.date(2020, 1, 1)

# %%
weekday = date.weekday()
weekday
# Out:
# 2

# %% [markdown]
# Weekday va de 0 a 6, siendo 0 el lunes y 6 el domingo

# %%
weekday
# Out:
# 2

# %%
date.weekday()
# Out:
# 2

# %% [markdown]
# Voy a aplicar este cálculo a todas las filas de mi Dataframe

# %%
# Function to get the weekday
def get_weekday(row):
    date = datetime.date(int(row['year']), int(row['month']), int(row['day']))
    return date.weekday()

# Apply the function to each row and create a new column
result_df['weekday'] = result_df.apply(lambda row: get_weekday(row), axis=1)
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday
# 0        0.511111  0.492593  0.459259  0.394444        2
# 1        0.283333  0.364815  0.298148  0.233333        2
# 2        0.248148  0.262963  0.342593  0.337037        2
# 3        0.381481  0.335185  0.244444  0.211111        2
# 4        0.079630  0.209259  0.418519  0.492593        2
# ...           ...       ...       ...       ...      ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6
# 2641511  0.555556  0.537037  0.490741  0.435185        6
# 2641512  0.490741  0.412037  0.551282  0.646465        6
# 2641513  0.879630  0.819444  0.768519  0.699074        6
# 2641514  0.722222  0.643519  0.736111  0.731481        6
#
# [2641515 rows x 11 columns]

# %% [markdown]
# ## Tarea: Añadir una nueva columna con información sobre si es fin de de semana

# %%
# Function to check if a date is a weekend
def is_weekened(row):
    weekday = row['weekday']
    if weekday == 5 or weekday == 6:
      return True
    return False


# Apply the function to each row and create a new column
result_df['is_weekend'] = result_df.apply(lambda row: is_weekened(row), axis=1)
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend
# 0        0.511111  0.492593  0.459259  0.394444        2       False
# 1        0.283333  0.364815  0.298148  0.233333        2       False
# 2        0.248148  0.262963  0.342593  0.337037        2       False
# 3        0.381481  0.335185  0.244444  0.211111        2       False
# 4        0.079630  0.209259  0.418519  0.492593        2       False
# ...           ...       ...       ...       ...      ...         ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6        True
# 2641511  0.555556  0.537037  0.490741  0.435185        6        True
# 2641512  0.490741  0.412037  0.551282  0.646465        6        True
# 2641513  0.879630  0.819444  0.768519  0.699074        6        True
# 2641514  0.722222  0.643519  0.736111  0.731481        6        True
#
# [2641515 rows x 12 columns]

# %% [markdown]
# ## Tarea: Añadir una nueva columna con información sobre si es festivo

# %%
# Function to check if a date is a holiday
def is_holiday(row):
    date = datetime.date(row['year'], row['month'], row['day'])

    # Initialize the holidays library for the given country, spain ES
    holiday_list = holidays.ES()

    return date in holiday_list

# Apply the function to each row and create a new column
result_df['is_festive'] = result_df.apply(lambda row: is_holiday(row), axis=1)
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend  \
# 0        0.511111  0.492593  0.459259  0.394444        2       False
# 1        0.283333  0.364815  0.298148  0.233333        2       False
# 2        0.248148  0.262963  0.342593  0.337037        2       False
# 3        0.381481  0.335185  0.244444  0.211111        2       False
# 4        0.079630  0.209259  0.418519  0.492593        2       False
# ...           ...       ...       ...       ...      ...         ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6        True
# 2641511  0.555556  0.537037  0.490741  0.435185        6        True
# 2641512  0.490741  0.412037  0.551282  0.646465        6        True
# 2641513  0.879630  0.819444  0.768519  0.699074        6        True
# 2641514  0.722222  0.643519  0.736111  0.731481        6        True
#
#          is_festive
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 2641510       False
# 2641511       False
# 2641512       False
# 2641513       False
# 2641514       False
#
# [2641515 rows x 13 columns]

# %%
result_df.to_csv('/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/3 attempt/preprocessed_data_ctxs_weekdays.csv', index=False)

# %%
result_df = pd.read_csv('/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/3 attempt/preprocessed_data_ctxs_weekdays.csv')
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend  \
# 0        0.511111  0.492593  0.459259  0.394444        2       False
# 1        0.283333  0.364815  0.298148  0.233333        2       False
# 2        0.248148  0.262963  0.342593  0.337037        2       False
# 3        0.381481  0.335185  0.244444  0.211111        2       False
# 4        0.079630  0.209259  0.418519  0.492593        2       False
# ...           ...       ...       ...       ...      ...         ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6        True
# 2641511  0.555556  0.537037  0.490741  0.435185        6        True
# 2641512  0.490741  0.412037  0.551282  0.646465        6        True
# 2641513  0.879630  0.819444  0.768519  0.699074        6        True
# 2641514  0.722222  0.643519  0.736111  0.731481        6        True
#
#          is_festive
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 2641510       False
# 2641511       False
# 2641512       False
# 2641513       False
# 2641514       False
#
# [2641515 rows x 13 columns]

# %% [markdown]
# Voy a leer el archivo de información para obtener datos de ubicación de las estaciones

# %%
filepath_info = '/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/Informacio_Estacions_Bicing.csv'
df_info = pd.read_csv(filepath_info, sep=',')
df_info
# Out:
#      station_id                                 name physical_configuration  \
# 0             1        GRAN VIA CORTS CATALANES, 760    ELECTRICBIKESTATION
# 1             2                C/ ROGER DE FLOR, 126    ELECTRICBIKESTATION
# 2             3                        C/ NÀPOLS, 82    ELECTRICBIKESTATION
# 3             4                         C/ RIBES, 13    ELECTRICBIKESTATION
# 4             5  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)    ELECTRICBIKESTATION
# ..          ...                                  ...                    ...
# 501         515                    C/ SANT ADRIÀ, 43    ELECTRICBIKESTATION
# 502         516                    C/ SANT ADRIÀ, 88    ELECTRICBIKESTATION
# 503         517             AV. RASOS DE PEGUERA, 10    ELECTRICBIKESTATION
# 504         518                    C/ LLOBREGÓS, 115    ELECTRICBIKESTATION
# 505         519                       C/ PEDRELL, 52    ELECTRICBIKESTATION
#
#            lat       lon  altitude                              address  \
# 0    41.397978  2.180107      16.0        GRAN VIA CORTS CATALANES, 760
# 1    41.395488  2.177198      17.0                C/ ROGER DE FLOR, 126
# 2    41.394156  2.181331      11.0                        C/ NÀPOLS, 82
# 3    41.393317  2.181248       8.0                         C/ RIBES, 13
# 4    41.391103  2.180176       7.0  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)
# ..         ...       ...       ...                                  ...
# 501  41.435207  2.194800      19.0                    C/ SANT ADRIÀ, 43
# 502  41.435460  2.200157      15.0                    C/ SANT ADRIÀ, 88
# 503  41.462095  2.178959      44.0             AV. RASOS DE PEGUERA, 10
# 504  41.424689  2.157049     112.0                    C/ LLOBREGÓS, 115
# 505  41.424655  2.166289     110.0                       C/ PEDRELL, 52
#
#      post_code  capacity  is_charging_station  nearby_distance  \
# 0         8013        45                 True           1000.0
# 1         8013        29                 True           1000.0
# 2         8013        27                 True           1000.0
# 3         8013        21                 True           1000.0
# 4         8018        39                 True           1000.0
# ..         ...       ...                  ...              ...
# 501       8030        24                 True           1000.0
# 502       8030        21                 True           1000.0
# 503       8033        20                 True           1000.0
# 504       8032        27                 True           1000.0
# 505       8032        24                 True           1000.0
#
#      _ride_code_support  rental_uris cross_street
# 0                  True          NaN          NaN
# 1                  True          NaN          NaN
# 2                  True          NaN          NaN
# 3                  True          NaN          NaN
# 4                  True          NaN          NaN
# ..                  ...          ...          ...
# 501                True          NaN          NaN
# 502                True          NaN          NaN
# 503                True          NaN          NaN
# 504                True          NaN          NaN
# 505                True          NaN          NaN
#
# [506 rows x 14 columns]

# %%
df_info[['station_id', 'lat', 'lon', 'post_code']]
# Out:
#      station_id        lat       lon  post_code
# 0             1  41.397978  2.180107       8013
# 1             2  41.395488  2.177198       8013
# 2             3  41.394156  2.181331       8013
# 3             4  41.393317  2.181248       8013
# 4             5  41.391103  2.180176       8018
# ..          ...        ...       ...        ...
# 501         515  41.435207  2.194800       8030
# 502         516  41.435460  2.200157       8030
# 503         517  41.462095  2.178959       8033
# 504         518  41.424689  2.157049       8032
# 505         519  41.424655  2.166289       8032
#
# [506 rows x 4 columns]

# %% [markdown]
# Para pintar el mapa tuve en cuenta o en consideracion las variables de latitud y longitud de las ubicaciones de las estaciones.

# %%
lats = df_info['lat'][:]

# %%
lons = df_info['lon'][:]

# %%
post_codes = df_info['post_code'][:]

# %% [markdown]
# Identique que todas las estaciones estan contenidas en Barcelona.

# %%
cities = ['Barcelona'] * len(lats)

# %% [markdown]
# Identifique que los valores son constantes pues por ahora no lo voy a usar.

# %%
values = [1] * len(lats)

# %% [markdown]
# Instale Folium para dibujar mapas

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.6.2)

# %% [markdown]
# El siguiente codigo es para dibujar un mapa con la información de la ubicación de las estaciones, adicionando la información sobre el código postal, a la que se puede acceder desde el mapa interactivo.
# Pulsando sobre cualquier estación.

# %%
import folium
import pandas as pd

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14cbb223c42d3948a479e389eecb33aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14cbb223c42d3948a479e389eecb33aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14cbb223c42d3948a479e389eecb33aa = L.map(
#                 &quot;map_14cbb223c42d3948a479e389eecb33aa&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ac6a7a626ac6a34ca87dc8be59edf4b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_14cbb223c42d3948a479e389eecb33aa);
#
#
#             var circle_marker_c048f5149a56fb16d4734e51c48284fc = L.circleMarker(
#                 [41.3979779, 2.1801069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_14cbb223c42d3948a479e389eecb33aa);
#
#
#         var popup_e4f1dfb1a4cb813c420d5da1cf33176f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bd09478270d21e29f55c4b897482fd5 = $(`&lt;div id=&quot;html_9bd09478270d21e29f55c4b897482fd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;/div&gt;`)[0];
#                 popup_e4f1dfb1a4cb813c420d5da1cf33176f.setContent(html_9bd09478270d21e29f55c4b897482fd5);
#
#
#
#         circle_marker_c048f5149a56fb16d4734e51c48284fc.bindPopup(popup_e4f1dfb1a4cb813c420d5da1cf33176f)
#         ;
#
#
#
#
#             var circle_marker_88c36fdcad51241e71fe4df0306bbd45 = L.circleMarker(
#                 [41.3954877, 2.1771985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_14cbb223c42d3948a479e389eecb33aa);
#
#
#         var popup_0554c98a9879e6fd527b7ce6aac722db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0851ffdc4e142c33fcb5c69392c10fb1 = $(`&lt;div id=&quot;html_0851ffdc4e142c33fcb5c69392c10fb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;/div&gt;`)[0];
#                 popup_0554c98a9879e6fd527b7ce6aac722db.setContent(html_0851ffdc4e142c33fcb5c69392c10fb1);
#
#
#
#         circle_marker_88c36fdcad51241e71fe4df0306bbd45.bindPopup(popup_0554c98a9879e6fd527b7ce6aac722db)
#         ;
#
#
#
#
#             var circle_marker_659bd1eff58d905b4a919cb17eeb81ec = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_14cbb223c42d3948a479e389eecb33aa);
#
#
#         var popup_b34cbf7f0827a2911f4643b3f361dbf9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_226184b68a4c002cb1f85ff3afcc8eb1 = $(`&lt;div id=&quot;html_226184b68a4c002cb1f85ff3afcc8eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;/div&gt;`)[0];
#                 popup_b34cbf7f0827a2911f4643b3f361dbf9.setContent(html_226184b68a4c002cb1f85ff3afcc8eb1);
#
#
#
#         circle_marker_659bd1eff58d905b4a919cb17eeb81ec.bindPopup(popup_b34cbf7f0827a2911f4643b3f361dbf9)
#         ;
#
#
#
#
#             var circle_marker_3b0635527862b49869dc0d16bdefbb36 = L.circleMarker(
#                 [41.3933173, 2.1812483],
#                 {&quot;bubblingMouseEvent

# %% [markdown]
# Luego de verificar que el mapa funciona, voy a tomar los datos de 2023, que es el ano mas actual que tengo. Para realizar un analisis en este ano.

# %% [markdown]
# Voy a filtar solo por el ano 2023

# %%
result_df_2023 = result_df[result_df['year']==2023]
result_df_2023['station_id'] = result_df_2023['station_id'].astype(int)

result_df_2023.head()
# Out:
# <ipython-input-27-67b5865d3946>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df_2023['station_id'] = result_df_2023['station_id'].astype(int)
#       station_id  year  month  day  hour  percentage_docks_available  \
# 4995           1  2023      1    1   2.0                    0.161111
# 4996           1  2023      1    1   7.0                    0.146296
# 4997           1  2023      1    1  12.0                    0.198148
# 4998           1  2023      1    1  17.0                    0.364815
# 4999           1  2023      1    1  22.0                    0.548148
#
#          ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend  is_festive
# 4995  0.177778  0.185185  0.187037  0.148148        6        True       False
# 4996  0.138889  0.146296  0.129630  0.153704        6        True       False
# 4997  0.190741  0.222222  0.209259  0.200000        6        True       False
# 4998  0.200000  0.300000  0.307407  0.342593        6        True       False
# 4999  0.394444  0.283333  0.224074  0.294444        6        True       False

# %% [markdown]
# Filtre los datos con Muelles Disponibles por debajo del 20% para **días entre semana y NO festivos** .
#
# Guarde las estaciones con ese indicador.

# %%
station_ids_weekday_nofestive = result_df_2023[(result_df_2023['is_festive'] == False) & (result_df_2023['is_weekend'] == False) & (result_df_2023['percentage_docks_available'] < 0.2)]['station_id'].values

# %%
import numpy as np

station_ids_weekday_nofestive = list(np.unique(station_ids_weekday_nofestive))

# %%
len(station_ids_weekday_nofestive)
# Out:
# 399

# %% [markdown]
# Filtre los datos con muelles disponibles por debajo del 20% para **días en fin de semana o festivos** .
#
# Guarde las estaciones con ese indicador.

# %%
station_ids_weekend_festive = result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['percentage_docks_available'] < 0.2)]

# %%
import numpy as np

station_ids_weekend_festive = list(np.unique(station_ids_weekend_festive))

# %%
len(station_ids_weekday_nofestive)
# Out:
# 399

# %% [markdown]
# Identifico que todas las estaciones (399) están alguna vez en esta situación, seguramente por la recolocación de bicicletas.
#
# Voy a probar otros filtros por ejemplo por horas.

# %%
station_ids_weekday_nofestive = list(np.unique(result_df_2023[(result_df_2023['is_festive'] == False) & (result_df_2023['is_weekend'] == False) & (result_df_2023['hour'] > 8) & (result_df_2023['hour'] < 10) & (result_df_2023['percentage_docks_available'] == 0.0)]['station_id'].values))
len(station_ids_weekday_nofestive)
# Out:
# 45

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids = set(station_ids_weekday_nofestive)

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekday_nofestive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20c8c212ba3132eb6375525f66a013f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20c8c212ba3132eb6375525f66a013f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20c8c212ba3132eb6375525f66a013f5 = L.map(
#                 &quot;map_20c8c212ba3132eb6375525f66a013f5&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8dc260980e6c98b7846d5190f2fe298 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_20c8c212ba3132eb6375525f66a013f5);
#
#
#             var circle_marker_10becf4520676ccec13225217640ed98 = L.circleMarker(
#                 [41.3833653, 2.1946255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_20c8c212ba3132eb6375525f66a013f5);
#
#
#         var popup_c1a1d0ae125a1eee2e057db776a9672b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db1267a5b0e253bc1f2e61152319547d = $(`&lt;div id=&quot;html_db1267a5b0e253bc1f2e61152319547d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 12&lt;/div&gt;`)[0];
#                 popup_c1a1d0ae125a1eee2e057db776a9672b.setContent(html_db1267a5b0e253bc1f2e61152319547d);
#
#
#
#         circle_marker_10becf4520676ccec13225217640ed98.bindPopup(popup_c1a1d0ae125a1eee2e057db776a9672b)
#         ;
#
#
#
#
#             var circle_marker_e58ced8bcd61e1dddf14580e3eb52791 = L.circleMarker(
#                 [41.3924661, 2.1717397],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_20c8c212ba3132eb6375525f66a013f5);
#
#
#         var popup_71b134847f37a741a68d0f7ac2ce3eb4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3437c8218c2c2cdccfae86a1f9f6e1fc = $(`&lt;div id=&quot;html_3437c8218c2c2cdccfae86a1f9f6e1fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8010&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 23&lt;/div&gt;`)[0];
#                 popup_71b134847f37a741a68d0f7ac2ce3eb4.setContent(html_3437c8218c2c2cdccfae86a1f9f6e1fc);
#
#
#
#         circle_marker_e58ced8bcd61e1dddf14580e3eb52791.bindPopup(popup_71b134847f37a741a68d0f7ac2ce3eb4)
#         ;
#
#
#
#
#             var circle_marker_fce6e82b3f61d3fc59937c6776175fe8 = L.circleMarker(
#                 [41.4134833, 2.2206913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_20c8c212ba3132eb6375525f66a013f5);
#
#
#         var popup_c7737ece3597125cea2c1163aad935c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfab5435313f9f3162c73768e38150d8 = $(`&lt;div id=&quot;html_cfab5435313f9f3162c73768e38150d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8930&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 35&lt;/div&gt;`)[0];
#                 popup_c7737ece3597125cea2c1163aad935c8.setContent(html_cfab5435313f9f3162c73768e38150d8);
#
#
#
#         circle_marker_fce6e82b3f61d3fc59937c6776175fe8.bindPopup(popup_c7737ece3597125cea2c1163aad935c8)
#         ;
#
#
#
#
#             var circle_marker_862cb27d4a2713536e067682029983a0 = L.circleMarker(
#                 [41.3850616, 2.176

# %% [markdown]
# Con el codigo anterior podemos localizar las estaciones que se encuentran llenas a primera hora de la mañana en dias laborables, seguramente coincidiendo con puntos de gran afluencia de empresas.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 8) & (result_df_2023['hour'] < 10) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 17

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids = set(station_ids_weekend_festive) & union_ids
union_ids
# Out:
# {57, 124, 286}

# %% [markdown]
# Estas 4 estaciones tiene problemas de disponibilidad de huecos entre las 8 y las 10, independientemente de si es fin de semana o festivo o no.

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41f80db58defeb00a13c46d2169bd061 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41f80db58defeb00a13c46d2169bd061&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41f80db58defeb00a13c46d2169bd061 = L.map(
#                 &quot;map_41f80db58defeb00a13c46d2169bd061&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6034522a16fbe91746f856f8a4f8738c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_41f80db58defeb00a13c46d2169bd061);
#
#
#             var circle_marker_2493d24745e8d621d8bf08cf91e41551 = L.circleMarker(
#                 [41.384844, 2.185085],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_41f80db58defeb00a13c46d2169bd061);
#
#
#         var popup_e5a21f91c86cde1367f4cd5759fc947d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a90e3a92f1c3bf3f2d8c1cc5cefaa226 = $(`&lt;div id=&quot;html_a90e3a92f1c3bf3f2d8c1cc5cefaa226&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 14&lt;/div&gt;`)[0];
#                 popup_e5a21f91c86cde1367f4cd5759fc947d.setContent(html_a90e3a92f1c3bf3f2d8c1cc5cefaa226);
#
#
#
#         circle_marker_2493d24745e8d621d8bf08cf91e41551.bindPopup(popup_e5a21f91c86cde1367f4cd5759fc947d)
#         ;
#
#
#
#
#             var circle_marker_194e44fa65a5d9197bcc97218f50550f = L.circleMarker(
#                 [41.385086, 2.174016],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_41f80db58defeb00a13c46d2169bd061);
#
#
#         var popup_c7476e7962b3fe88d3a7d6246b595c42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e3d511e9d35fc48475fb885f46cb0e25 = $(`&lt;div id=&quot;html_e3d511e9d35fc48475fb885f46cb0e25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8002&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 53&lt;/div&gt;`)[0];
#                 popup_c7476e7962b3fe88d3a7d6246b595c42.setContent(html_e3d511e9d35fc48475fb885f46cb0e25);
#
#
#
#         circle_marker_194e44fa65a5d9197bcc97218f50550f.bindPopup(popup_c7476e7962b3fe88d3a7d6246b595c42)
#         ;
#
#
#
#
#             var circle_marker_d48b428f5f245c61416b58a35e93b795 = L.circleMarker(
#                 [41.377187, 2.176757],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_41f80db58defeb00a13c46d2169bd061);
#
#
#         var popup_4b2f08e3189cb12f4bf38824552d389d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d009b33b0266f8e1ea3cf2129625cbe = $(`&lt;div id=&quot;html_8d009b33b0266f8e1ea3cf2129625cbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8002&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 57&lt;/div&gt;`)[0];
#                 popup_4b2f08e3189cb12f4bf38824552d389d.setContent(html_8d009b33b0266f8e1ea3cf2129625cbe);
#
#
#
#         circle_marker_d48b428f5f245c61416b58a35e93b795.bindPopup(popup_4b2f08e3189cb12f4bf38824552d389d)
#         ;
#
#
#
#
#             var circle_marker_24107c6073f53d7bf4f93aa747dad10a = L.circleMarker(
#                 [41.387696, 2.1696543],

# %% [markdown]
# En fines de semana solo hay 14 estaciones que alguna vez están llenas en ese horario.
#
# Por tanto, considero que no es tan problemático este momento.
#
# Sin embargo, puedo buscar otros escenarios más interesantes para estas fechas.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 12) & (result_df_2023['hour'] < 18) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 70

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids2 = set(station_ids_weekend_festive)

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e16a35ebcdae5dbc04295b015e89dd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e16a35ebcdae5dbc04295b015e89dd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e16a35ebcdae5dbc04295b015e89dd6 = L.map(
#                 &quot;map_4e16a35ebcdae5dbc04295b015e89dd6&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71fb5315df56e709ecbf934a6ce7f578 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4e16a35ebcdae5dbc04295b015e89dd6);
#
#
#             var circle_marker_a676718396bf8e97f5e039a5b378fa18 = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e16a35ebcdae5dbc04295b015e89dd6);
#
#
#         var popup_8362124e2e5667d4512c19428b77790a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82f80b484f6ed7be3f9ad7d0527b22d2 = $(`&lt;div id=&quot;html_82f80b484f6ed7be3f9ad7d0527b22d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 3&lt;/div&gt;`)[0];
#                 popup_8362124e2e5667d4512c19428b77790a.setContent(html_82f80b484f6ed7be3f9ad7d0527b22d2);
#
#
#
#         circle_marker_a676718396bf8e97f5e039a5b378fa18.bindPopup(popup_8362124e2e5667d4512c19428b77790a)
#         ;
#
#
#
#
#             var circle_marker_de6b042707be8fc930dd4f6ac33abfce = L.circleMarker(
#                 [41.384546, 2.184922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e16a35ebcdae5dbc04295b015e89dd6);
#
#
#         var popup_9fa6fd25fbb2b2da1bc8d6007d8e02dd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3299b345290baab6e4be238c65649d03 = $(`&lt;div id=&quot;html_3299b345290baab6e4be238c65649d03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 9&lt;/div&gt;`)[0];
#                 popup_9fa6fd25fbb2b2da1bc8d6007d8e02dd.setContent(html_3299b345290baab6e4be238c65649d03);
#
#
#
#         circle_marker_de6b042707be8fc930dd4f6ac33abfce.bindPopup(popup_9fa6fd25fbb2b2da1bc8d6007d8e02dd)
#         ;
#
#
#
#
#             var circle_marker_e1f0fe7c7866a2daaa5b9d8c2b0532e0 = L.circleMarker(
#                 [41.388143, 2.195551],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4e16a35ebcdae5dbc04295b015e89dd6);
#
#
#         var popup_5390d334317ef20f661e3949560e4e01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77fff5bffb4f4b196afca37b5c197798 = $(`&lt;div id=&quot;html_77fff5bffb4f4b196afca37b5c197798&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8005&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 13&lt;/div&gt;`)[0];
#                 popup_5390d334317ef20f661e3949560e4e01.setContent(html_77fff5bffb4f4b196afca37b5c197798);
#
#
#
#         circle_marker_e1f0fe7c7866a2daaa5b9d8c2b0532e0.bindPopup(popup_5390d334317ef20f661e3949560e4e01)
#         ;
#
#
#
#
#             var circle_marker_77b0324ab25af36f64a10502d9d0650d = L.circleMarker(
#                 [41.384844, 2.185085],

# %% [markdown]
# Por ejemplo, es interesante ver cómo los días festivos y fines de semanas, las estaciones pegadas al paseo marítimo y al borde de la playa están llenas en algún momento entre las 12 y las 18 del día, coincidiendo con las horas donde todavia hay claridad (es de dia) para aprovechar la playa.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 19) & (result_df_2023['hour'] < 23) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 46

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids2 = set(station_ids_weekend_festive) & union_ids2
union_ids2
# Out:
# {9,
#  55,
#  57,
#  88,
#  104,
#  117,
#  133,
#  147,
#  157,
#  158,
#  171,
#  176,
#  178,
#  179,
#  260,
#  269,
#  279,
#  284,
#  340,
#  348,
#  361,
#  389,
#  392,
#  402,
#  425}

# %% [markdown]
# Y esta lista de estaciones tiene problemas con muelles disponibles entre las 12 y las 6 y entre las 7 y las 23 durante festivos y fines de semana por lo que habría que reforzarlas.

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_233ecb7db0f2be039d9a50c16b1cdad0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_233ecb7db0f2be039d9a50c16b1cdad0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_233ecb7db0f2be039d9a50c16b1cdad0 = L.map(
#                 &quot;map_233ecb7db0f2be039d9a50c16b1cdad0&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc058a2a6c11177f8f58ddd34e7fdded = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_233ecb7db0f2be039d9a50c16b1cdad0);
#
#
#             var circle_marker_9a02c39bd897c1e0b9243397a6feb6ba = L.circleMarker(
#                 [41.384546, 2.184922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_233ecb7db0f2be039d9a50c16b1cdad0);
#
#
#         var popup_1833ff805bb1a1b6a5b88bab4507fd41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9543e5d27aa3445e85e4a397463cd74f = $(`&lt;div id=&quot;html_9543e5d27aa3445e85e4a397463cd74f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 9&lt;/div&gt;`)[0];
#                 popup_1833ff805bb1a1b6a5b88bab4507fd41.setContent(html_9543e5d27aa3445e85e4a397463cd74f);
#
#
#
#         circle_marker_9a02c39bd897c1e0b9243397a6feb6ba.bindPopup(popup_1833ff805bb1a1b6a5b88bab4507fd41)
#         ;
#
#
#
#
#             var circle_marker_e53f90a627e0dce5030a0d6fe793c2b6 = L.circleMarker(
#                 [41.3812425, 2.1933482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_233ecb7db0f2be039d9a50c16b1cdad0);
#
#
#         var popup_8426faf5bca254387713c6891d598269 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da535a647c7787003a520ecff283bccf = $(`&lt;div id=&quot;html_da535a647c7787003a520ecff283bccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 11&lt;/div&gt;`)[0];
#                 popup_8426faf5bca254387713c6891d598269.setContent(html_da535a647c7787003a520ecff283bccf);
#
#
#
#         circle_marker_e53f90a627e0dce5030a0d6fe793c2b6.bindPopup(popup_8426faf5bca254387713c6891d598269)
#         ;
#
#
#
#
#             var circle_marker_12006a456aaeed36da25dcf2befecf24 = L.circleMarker(
#                 [41.3775319, 2.1707321],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_233ecb7db0f2be039d9a50c16b1cdad0);
#
#
#         var popup_3851aa3504d34cca2cb88a6e4c248f46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_093005a8e11b7f1da22e4a1b075e6647 = $(`&lt;div id=&quot;html_093005a8e11b7f1da22e4a1b075e6647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8001&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 54&lt;/div&gt;`)[0];
#                 popup_3851aa3504d34cca2cb88a6e4c248f46.setContent(html_093005a8e11b7f1da22e4a1b075e6647);
#
#
#
#         circle_marker_12006a456aaeed36da25dcf2befecf24.bindPopup(popup_3851aa3504d34cca2cb88a6e4c248f46)
#         ;
#
#
#
#
#             var circle_marker_d809b7b6e8c9a5bace61973940e30404 = L.circleMarker(
#                 [41.3811923, 2.173500

# %% [markdown]
# No ocurre lo mismo entre las 19 y las 23h, donde las estaciones del centro parece estar saturadas.

# %% [markdown]
# Todos estos datos me sirven para verificar/identificar estaciones que se colapsan y habría que ampliar de tamaño o llenar/vaciar de bicicletas con más frecuencia en ciertos tramos horarios.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 12) & (result_df_2023['hour'] < 23) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 101

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21bbdb453504c4df88e35c075dd3439c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21bbdb453504c4df88e35c075dd3439c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21bbdb453504c4df88e35c075dd3439c = L.map(
#                 &quot;map_21bbdb453504c4df88e35c075dd3439c&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6243ec4f4549c56d4e3c7c1b1827e015 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21bbdb453504c4df88e35c075dd3439c);
#
#
#             var circle_marker_fc7579d6574110676f4e8e231c6dd6c3 = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_21bbdb453504c4df88e35c075dd3439c);
#
#
#         var popup_2b8f5c37037e336950035b49ac5f9445 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae26372719931edbdb747b2b8c8ba8c9 = $(`&lt;div id=&quot;html_ae26372719931edbdb747b2b8c8ba8c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 3&lt;/div&gt;`)[0];
#                 popup_2b8f5c37037e336950035b49ac5f9445.setContent(html_ae26372719931edbdb747b2b8c8ba8c9);
#
#
#
#         circle_marker_fc7579d6574110676f4e8e231c6dd6c3.bindPopup(popup_2b8f5c37037e336950035b49ac5f9445)
#         ;
#
#
#
#
#             var circle_marker_643bc66016d595e755cb5c30718f45df = L.circleMarker(
#                 [41.384546, 2.184922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_21bbdb453504c4df88e35c075dd3439c);
#
#
#         var popup_5f40a4a08acb1feffce3a8fcdd565843 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae3983e599705204aa22bc46c06db182 = $(`&lt;div id=&quot;html_ae3983e599705204aa22bc46c06db182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 9&lt;/div&gt;`)[0];
#                 popup_5f40a4a08acb1feffce3a8fcdd565843.setContent(html_ae3983e599705204aa22bc46c06db182);
#
#
#
#         circle_marker_643bc66016d595e755cb5c30718f45df.bindPopup(popup_5f40a4a08acb1feffce3a8fcdd565843)
#         ;
#
#
#
#
#             var circle_marker_3d994c3ad981f409949e946f2cfd50de = L.circleMarker(
#                 [41.3812425, 2.1933482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_21bbdb453504c4df88e35c075dd3439c);
#
#
#         var popup_e5048982fa7e1c0286f7387dda1fddd5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cddbae345e651a18d5a630cca5f09b01 = $(`&lt;div id=&quot;html_cddbae345e651a18d5a630cca5f09b01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 11&lt;/div&gt;`)[0];
#                 popup_e5048982fa7e1c0286f7387dda1fddd5.setContent(html_cddbae345e651a18d5a630cca5f09b01);
#
#
#
#         circle_marker_3d994c3ad981f409949e946f2cfd50de.bindPopup(popup_e5048982fa7e1c0286f7387dda1fddd5)
#         ;
#
#
#
#
#             var circle_marker_05844ff1f141fac23785ec28bb341a60 = L.circleMarker(
#                 [41.388143, 2.195551],

# %% [markdown]
# Por ultimo, voy a mostrar las estaciones llenas en festivos y fines de semana entre las 12 y las 23, mostrando lugares desde donde más gente toma bicicletas para desplazarse en el fin de semana, por lo que serían éstas estaciones las que habría que llenar con las bicicletas obtenidas anteriormente de las estaciones saturadas por el centro o la playa.

# %% [markdown]
# ## Analisis mapa con información del porcentaje de muelles disponibles

# %% [markdown]
# Primero filtre los datos por festivos o fin de semana y en el horario entre las 12 y las 18.
#
# Después saque/identifique/genere la media del valor de la proporción de muelles disponibles en ese tramo horario para cada estación.

# %%
result_df_2023_filtered = result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 12) & (result_df_2023['hour'] < 23)]
result_df_2023_filtered = result_df_2023_filtered[['station_id', 'percentage_docks_available']].groupby('station_id').mean()
result_df_2023_filtered = result_df_2023_filtered.reset_index()
result_df_2023_filtered
# Out:
#      station_id  percentage_docks_available
# 0             1                    0.769158
# 1             2                    0.663473
# 2             3                    0.499445
# 3             4                    0.496202
# 4             5                    0.635562
# ..          ...                         ...
# 394         474                    0.831421
# 395         492                    0.536327
# 396         494                    0.562992
# 397         495                    0.529004
# 398         496                    0.574929
#
# [399 rows x 2 columns]

# %% [markdown]
# Pege/integre la media de la proporción de muelles disponibles con la información de las estaciones para hacer el mapa.

# %%
df_filtered = df_info[df_info['station_id'].isin(list(result_df_2023_filtered['station_id'].values))]

# %%
df_merged = pd.merge(df_filtered, result_df_2023_filtered, on='station_id', how='left')

df_merged.head()
# Out:
#    station_id                                 name physical_configuration  \
# 0           1        GRAN VIA CORTS CATALANES, 760    ELECTRICBIKESTATION
# 1           2                C/ ROGER DE FLOR, 126    ELECTRICBIKESTATION
# 2           3                        C/ NÀPOLS, 82    ELECTRICBIKESTATION
# 3           4                         C/ RIBES, 13    ELECTRICBIKESTATION
# 4           5  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)    ELECTRICBIKESTATION
#
#          lat       lon  altitude                              address  \
# 0  41.397978  2.180107      16.0        GRAN VIA CORTS CATALANES, 760
# 1  41.395488  2.177198      17.0                C/ ROGER DE FLOR, 126
# 2  41.394156  2.181331      11.0                        C/ NÀPOLS, 82
# 3  41.393317  2.181248       8.0                         C/ RIBES, 13
# 4  41.391103  2.180176       7.0  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)
#
#    post_code  capacity  is_charging_station  nearby_distance  \
# 0       8013        45                 True           1000.0
# 1       8013        29                 True           1000.0
# 2       8013        27                 True           1000.0
# 3       8013        21                 True           1000.0
# 4       8018        39                 True           1000.0
#
#    _ride_code_support  rental_uris cross_street  percentage_docks_available
# 0                True          NaN          NaN                    0.769158
# 1                True          NaN          NaN                    0.663473
# 2                True          NaN          NaN                    0.499445
# 3                True          NaN          NaN                    0.496202
# 4                True          NaN          NaN                    0.635562

# %% [markdown]
# Contrui/hice el mapa con el tamaño de los círculos en función del Inverso del percetage_docks_available.
#
# 1-percetage_docks_available es la proporción de bicis disponibles en la estación.

# %%
lats = df_merged['lat'][:]
lons = df_merged['lon'][:]
post_codes = df_merged['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = 10*(1-df_merged['percentage_docks_available'][:])
ids = df_merged['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=row['value'],
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_566a270325b926b334bdd86d12c5bbe5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_566a270325b926b334bdd86d12c5bbe5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_566a270325b926b334bdd86d12c5bbe5 = L.map(
#                 &quot;map_566a270325b926b334bdd86d12c5bbe5&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec3dbf6fe8c4f4d381d7751fa99b004c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_566a270325b926b334bdd86d12c5bbe5);
#
#
#             var circle_marker_4bb6f4a0afacb71f7540564f177dd8e0 = L.circleMarker(
#                 [41.3979779, 2.1801069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.3084151801224975, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_566a270325b926b334bdd86d12c5bbe5);
#
#
#         var popup_6d384847feaba81dcf104583f45e5e09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f338b0808d4e14e5e7ee50f68eb0caf3 = $(`&lt;div id=&quot;html_f338b0808d4e14e5e7ee50f68eb0caf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 2.3084151801224975&lt;br&gt;Id: 1&lt;/div&gt;`)[0];
#                 popup_6d384847feaba81dcf104583f45e5e09.setContent(html_f338b0808d4e14e5e7ee50f68eb0caf3);
#
#
#
#         circle_marker_4bb6f4a0afacb71f7540564f177dd8e0.bindPopup(popup_6d384847feaba81dcf104583f45e5e09)
#         ;
#
#
#
#
#             var circle_marker_01140031f3ce8e3507a6d3ec9b119391 = L.circleMarker(
#                 [41.3954877, 2.1771985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.3652733056891284, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_566a270325b926b334bdd86d12c5bbe5);
#
#
#         var popup_abac85a3dfc74912e64c94b4b3959352 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05690afc251170ee93b06556cb0f84c9 = $(`&lt;div id=&quot;html_05690afc251170ee93b06556cb0f84c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 3.3652733056891284&lt;br&gt;Id: 2&lt;/div&gt;`)[0];
#                 popup_abac85a3dfc74912e64c94b4b3959352.setContent(html_05690afc251170ee93b06556cb0f84c9);
#
#
#
#         circle_marker_01140031f3ce8e3507a6d3ec9b119391.bindPopup(popup_abac85a3dfc74912e64c94b4b3959352)
#         ;
#
#
#
#
#             var circle_marker_bdbe0d3b7e8ccba044357059659ea995 = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.005554923847607, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_566a270325b926b334bdd86d12c5bbe5);
#
#
#         var popup_a06df8dd856994d840fc5f1071034cf6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4e0945085b98a0259283d531f27126f3 = $(`&lt;div id=&quot;html_4e0945085b98a0259283d531f27126f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 5.005554923847607&lt;br&gt;Id: 3&lt;/div&gt;`)[0];
#                 popup_a06df8dd856994d840fc5f1071034cf6.setContent(html_4e0945085b98a0259283d531f27126f3);
#
#
#
#         circle_marker_bdbe0d3b7e8ccba044357059659ea995.bindPopup(popup_a06df8dd856994d840fc5f1071034cf6)
#         ;
#
#
#
#
#             var ci

# %% [markdown]
# Este último mapa muestra las estaciones según el nivel de saturación durante el día (12-23) de días festivos y fines de semanas.
#
# Las estaciones con más saturación tienen círculos más grandes, es decir, aquellas que tienen más bicicletas según capacidad y por tanto menos muelles disponibles.
#
#
# Claramente se ven las estaciones del centro y playa más saturadas que el resto de estaciones.

# %% [markdown]
# Mariona y Pere, si hacen click en alguna estación del mapa podran obtener/observar/analizar la información sobre esa estación como el Station_id o la proporción de bicicletas disponibles.
