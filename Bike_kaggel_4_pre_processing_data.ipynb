# %% [markdown]
# <a href="https://colab.research.google.com/github/jafuma0320/2024-Online-Bike-Availability-Prediction/blob/main/Bike_kaggel_4_pre_processing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para poder visualizar los mapas se aconseja realizar el siguiente proceso:
#
# 1. Abre/ingresa a https://nbviewer.org/
# 2. En la página principal de nbviewer, verás un campo de texto que dice "Enter the URL of a Notebook in GitHum".
# 3. Pega la URL en nbviewer
# 4. Visualiza tu notebook con las gráficas y mapas en nbviewer

# %%
 # !pip install --upgrade holidays
# Out:
# Requirement already satisfied: holidays in /usr/local/lib/python3.10/dist-packages (0.51)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from holidays) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->holidays) (1.16.0)

# %%
import pandas as pd
from collections import Counter
import datetime
import holidays

# %%
from google.colab import drive

# Mount the Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
result_df = pd.read_csv('/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/3 attempt/preprocessed_data_ctxs.csv')
result_df
# Out:
#          station_id    year  month   day  hour  percentage_docks_available  \
# 0               1.0  2020.0    1.0   1.0   3.0                    0.346296
# 1               1.0  2020.0    1.0   1.0   8.0                    0.235185
# 2               1.0  2020.0    1.0   1.0  13.0                    0.385185
# 3               1.0  2020.0    1.0   1.0  18.0                    0.177778
# 4               1.0  2020.0    1.0   1.0  23.0                    0.450000
# ...             ...     ...    ...   ...   ...                         ...
# 2641510       496.0  2023.0   12.0  31.0   3.0                    0.504630
# 2641511       496.0  2023.0   12.0  31.0   8.0                    0.388889
# 2641512       496.0  2023.0   12.0  31.0  13.0                    0.861111
# 2641513       496.0  2023.0   12.0  31.0  18.0                    0.666667
# 2641514       496.0  2023.0   12.0  31.0  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1
# 0        0.511111  0.492593  0.459259  0.394444
# 1        0.283333  0.364815  0.298148  0.233333
# 2        0.248148  0.262963  0.342593  0.337037
# 3        0.381481  0.335185  0.244444  0.211111
# 4        0.079630  0.209259  0.418519  0.492593
# ...           ...       ...       ...       ...
# 2641510  0.564815  0.518519  0.606481  0.523148
# 2641511  0.555556  0.537037  0.490741  0.435185
# 2641512  0.490741  0.412037  0.551282  0.646465
# 2641513  0.879630  0.819444  0.768519  0.699074
# 2641514  0.722222  0.643519  0.736111  0.731481
#
# [2641515 rows x 10 columns]

# %% [markdown]
# Converti a entero las columnas de la fecha

# %%
result_df['year'] = result_df['year'].astype(int)
result_df['month'] = result_df['month'].astype(int)
result_df['day'] = result_df['day'].astype(int)

# %%
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1
# 0        0.511111  0.492593  0.459259  0.394444
# 1        0.283333  0.364815  0.298148  0.233333
# 2        0.248148  0.262963  0.342593  0.337037
# 3        0.381481  0.335185  0.244444  0.211111
# 4        0.079630  0.209259  0.418519  0.492593
# ...           ...       ...       ...       ...
# 2641510  0.564815  0.518519  0.606481  0.523148
# 2641511  0.555556  0.537037  0.490741  0.435185
# 2641512  0.490741  0.412037  0.551282  0.646465
# 2641513  0.879630  0.819444  0.768519  0.699074
# 2641514  0.722222  0.643519  0.736111  0.731481
#
# [2641515 rows x 10 columns]

# %% [markdown]
# ## Tarea: Añadir una nueva columna con información sobre "Weekday"

# %% [markdown]
# Voy a probar primero con una muestra y luego si funciona lo aplico a toda la base.

# %%
year = result_df['year'][0]
month = result_df['month'][0]
day = result_df['day'][0]

# %%
date = datetime.date(year, month, day)
date
# Out:
# datetime.date(2020, 1, 1)

# %%
weekday = date.weekday()
weekday
# Out:
# 2

# %% [markdown]
# Weekday va de 0 a 6, siendo 0 el lunes y 6 el domingo.
#
# Segun la libreria.

# %%
weekday
# Out:
# 2

# %%
date.weekday()
# Out:
# 2

# %% [markdown]
# Voy a aplicar este cálculo a todas las filas de mi Dataframe

# %%
# Function to get the weekday
def get_weekday(row):
    date = datetime.date(int(row['year']), int(row['month']), int(row['day']))
    return date.weekday()

# Apply the function to each row and create a new column
result_df['weekday'] = result_df.apply(lambda row: get_weekday(row), axis=1)
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday
# 0        0.511111  0.492593  0.459259  0.394444        2
# 1        0.283333  0.364815  0.298148  0.233333        2
# 2        0.248148  0.262963  0.342593  0.337037        2
# 3        0.381481  0.335185  0.244444  0.211111        2
# 4        0.079630  0.209259  0.418519  0.492593        2
# ...           ...       ...       ...       ...      ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6
# 2641511  0.555556  0.537037  0.490741  0.435185        6
# 2641512  0.490741  0.412037  0.551282  0.646465        6
# 2641513  0.879630  0.819444  0.768519  0.699074        6
# 2641514  0.722222  0.643519  0.736111  0.731481        6
#
# [2641515 rows x 11 columns]

# %% [markdown]
# Agregue una nueva columna con información sobre si es Fin de de Semana

# %%
# Function to check if a date is a weekend
def is_weekened(row):
    weekday = row['weekday']
    if weekday == 5 or weekday == 6:
      return True
    return False

# Apply the function to each row and create a new column
result_df['is_weekend'] = result_df.apply(lambda row: is_weekened(row), axis=1)
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend
# 0        0.511111  0.492593  0.459259  0.394444        2       False
# 1        0.283333  0.364815  0.298148  0.233333        2       False
# 2        0.248148  0.262963  0.342593  0.337037        2       False
# 3        0.381481  0.335185  0.244444  0.211111        2       False
# 4        0.079630  0.209259  0.418519  0.492593        2       False
# ...           ...       ...       ...       ...      ...         ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6        True
# 2641511  0.555556  0.537037  0.490741  0.435185        6        True
# 2641512  0.490741  0.412037  0.551282  0.646465        6        True
# 2641513  0.879630  0.819444  0.768519  0.699074        6        True
# 2641514  0.722222  0.643519  0.736111  0.731481        6        True
#
# [2641515 rows x 12 columns]

# %% [markdown]
# Agregue una nueva columna con información sobre si es Festivo

# %%
# Function to check if a date is a holiday
def is_holiday(row):
    date = datetime.date(row['year'], row['month'], row['day'])

    # Initialize the holidays library for the given country, spain ES
    holiday_list = holidays.ES()

    return date in holiday_list

# Apply the function to each row and create a new column
result_df['is_festive'] = result_df.apply(lambda row: is_holiday(row), axis=1)
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend  \
# 0        0.511111  0.492593  0.459259  0.394444        2       False
# 1        0.283333  0.364815  0.298148  0.233333        2       False
# 2        0.248148  0.262963  0.342593  0.337037        2       False
# 3        0.381481  0.335185  0.244444  0.211111        2       False
# 4        0.079630  0.209259  0.418519  0.492593        2       False
# ...           ...       ...       ...       ...      ...         ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6        True
# 2641511  0.555556  0.537037  0.490741  0.435185        6        True
# 2641512  0.490741  0.412037  0.551282  0.646465        6        True
# 2641513  0.879630  0.819444  0.768519  0.699074        6        True
# 2641514  0.722222  0.643519  0.736111  0.731481        6        True
#
#          is_festive
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 2641510       False
# 2641511       False
# 2641512       False
# 2641513       False
# 2641514       False
#
# [2641515 rows x 13 columns]

# %%
result_df.to_csv('/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/3 attempt/preprocessed_data_ctxs_weekdays.csv', index=False)

# %%
result_df = pd.read_csv('/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/3 attempt/preprocessed_data_ctxs_weekdays.csv')
result_df
# Out:
#          station_id  year  month  day  hour  percentage_docks_available  \
# 0               1.0  2020      1    1   3.0                    0.346296
# 1               1.0  2020      1    1   8.0                    0.235185
# 2               1.0  2020      1    1  13.0                    0.385185
# 3               1.0  2020      1    1  18.0                    0.177778
# 4               1.0  2020      1    1  23.0                    0.450000
# ...             ...   ...    ...  ...   ...                         ...
# 2641510       496.0  2023     12   31   3.0                    0.504630
# 2641511       496.0  2023     12   31   8.0                    0.388889
# 2641512       496.0  2023     12   31  13.0                    0.861111
# 2641513       496.0  2023     12   31  18.0                    0.666667
# 2641514       496.0  2023     12   31  23.0                    0.717593
#
#             ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend  \
# 0        0.511111  0.492593  0.459259  0.394444        2       False
# 1        0.283333  0.364815  0.298148  0.233333        2       False
# 2        0.248148  0.262963  0.342593  0.337037        2       False
# 3        0.381481  0.335185  0.244444  0.211111        2       False
# 4        0.079630  0.209259  0.418519  0.492593        2       False
# ...           ...       ...       ...       ...      ...         ...
# 2641510  0.564815  0.518519  0.606481  0.523148        6        True
# 2641511  0.555556  0.537037  0.490741  0.435185        6        True
# 2641512  0.490741  0.412037  0.551282  0.646465        6        True
# 2641513  0.879630  0.819444  0.768519  0.699074        6        True
# 2641514  0.722222  0.643519  0.736111  0.731481        6        True
#
#          is_festive
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 2641510       False
# 2641511       False
# 2641512       False
# 2641513       False
# 2641514       False
#
# [2641515 rows x 13 columns]

# %% [markdown]
# Voy a leer el archivo "Informacio_Estacions_Bicing.csv" para obtener los datos de ubicación de las estaciones

# %%
filepath_info = '/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/Informacio_Estacions_Bicing.csv'
df_info = pd.read_csv(filepath_info, sep=',')
df_info
# Out:
#      station_id                                 name physical_configuration  \
# 0             1        GRAN VIA CORTS CATALANES, 760    ELECTRICBIKESTATION
# 1             2                C/ ROGER DE FLOR, 126    ELECTRICBIKESTATION
# 2             3                        C/ NÀPOLS, 82    ELECTRICBIKESTATION
# 3             4                         C/ RIBES, 13    ELECTRICBIKESTATION
# 4             5  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)    ELECTRICBIKESTATION
# ..          ...                                  ...                    ...
# 501         515                    C/ SANT ADRIÀ, 43    ELECTRICBIKESTATION
# 502         516                    C/ SANT ADRIÀ, 88    ELECTRICBIKESTATION
# 503         517             AV. RASOS DE PEGUERA, 10    ELECTRICBIKESTATION
# 504         518                    C/ LLOBREGÓS, 115    ELECTRICBIKESTATION
# 505         519                       C/ PEDRELL, 52    ELECTRICBIKESTATION
#
#            lat       lon  altitude                              address  \
# 0    41.397978  2.180107      16.0        GRAN VIA CORTS CATALANES, 760
# 1    41.395488  2.177198      17.0                C/ ROGER DE FLOR, 126
# 2    41.394156  2.181331      11.0                        C/ NÀPOLS, 82
# 3    41.393317  2.181248       8.0                         C/ RIBES, 13
# 4    41.391103  2.180176       7.0  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)
# ..         ...       ...       ...                                  ...
# 501  41.435207  2.194800      19.0                    C/ SANT ADRIÀ, 43
# 502  41.435460  2.200157      15.0                    C/ SANT ADRIÀ, 88
# 503  41.462095  2.178959      44.0             AV. RASOS DE PEGUERA, 10
# 504  41.424689  2.157049     112.0                    C/ LLOBREGÓS, 115
# 505  41.424655  2.166289     110.0                       C/ PEDRELL, 52
#
#      post_code  capacity  is_charging_station  nearby_distance  \
# 0         8013        45                 True           1000.0
# 1         8013        29                 True           1000.0
# 2         8013        27                 True           1000.0
# 3         8013        21                 True           1000.0
# 4         8018        39                 True           1000.0
# ..         ...       ...                  ...              ...
# 501       8030        24                 True           1000.0
# 502       8030        21                 True           1000.0
# 503       8033        20                 True           1000.0
# 504       8032        27                 True           1000.0
# 505       8032        24                 True           1000.0
#
#      _ride_code_support  rental_uris cross_street
# 0                  True          NaN          NaN
# 1                  True          NaN          NaN
# 2                  True          NaN          NaN
# 3                  True          NaN          NaN
# 4                  True          NaN          NaN
# ..                  ...          ...          ...
# 501                True          NaN          NaN
# 502                True          NaN          NaN
# 503                True          NaN          NaN
# 504                True          NaN          NaN
# 505                True          NaN          NaN
#
# [506 rows x 14 columns]

# %% [markdown]
# Seleccione las columnas de Latitud, Longitud y Codigo Post, que me podrian servir para el analisis que tengo en mente.

# %%
df_info[['station_id', 'lat', 'lon', 'post_code']]
# Out:
#      station_id        lat       lon  post_code
# 0             1  41.397978  2.180107       8013
# 1             2  41.395488  2.177198       8013
# 2             3  41.394156  2.181331       8013
# 3             4  41.393317  2.181248       8013
# 4             5  41.391103  2.180176       8018
# ..          ...        ...       ...        ...
# 501         515  41.435207  2.194800       8030
# 502         516  41.435460  2.200157       8030
# 503         517  41.462095  2.178959       8033
# 504         518  41.424689  2.157049       8032
# 505         519  41.424655  2.166289       8032
#
# [506 rows x 4 columns]

# %% [markdown]
# Para poder graficar/dibujar el mapa tuve en cuenta o en consideracion las variables de latitud, longitud y codigo postal de las ubicaciones de las estaciones.

# %%
lats = df_info['lat'][:]

# %%
lons = df_info['lon'][:]

# %%
post_codes = df_info['post_code'][:]

# %% [markdown]
# Identique que todas las estaciones estan contenidas en Barcelona.

# %%
cities = ['Barcelona'] * len(lats)

# %% [markdown]
# Identifique que los valores son constantes pues por ahora no lo voy a usar.

# %%
values = [1] * len(lats)

# %% [markdown]
# Instale Folium para dibujar mapas

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.6.2)

# %% [markdown]
# El siguiente codigo es para graficar/dibujar un mapa con la información de la ubicación de las estaciones, adicionando la información sobre el código postal, a la que se puede acceder desde el mapa interactivo.
#
# Pulsando sobre cualquier estación.

# %%
import folium
import pandas as pd

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d6244d71113293c01870e3978764409 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d6244d71113293c01870e3978764409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d6244d71113293c01870e3978764409 = L.map(
#                 &quot;map_9d6244d71113293c01870e3978764409&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32fe139d9413126e19ad3ede6aeb348e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9d6244d71113293c01870e3978764409);
#
#
#             var circle_marker_22407cb0c6b6b120f43a373d570eec00 = L.circleMarker(
#                 [41.3979779, 2.1801069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9d6244d71113293c01870e3978764409);
#
#
#         var popup_88fc5620d7e8ffd28ed1fc4555c2ba66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0b5889e18e10b73a520fd02097e2cf2 = $(`&lt;div id=&quot;html_a0b5889e18e10b73a520fd02097e2cf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;/div&gt;`)[0];
#                 popup_88fc5620d7e8ffd28ed1fc4555c2ba66.setContent(html_a0b5889e18e10b73a520fd02097e2cf2);
#
#
#
#         circle_marker_22407cb0c6b6b120f43a373d570eec00.bindPopup(popup_88fc5620d7e8ffd28ed1fc4555c2ba66)
#         ;
#
#
#
#
#             var circle_marker_74643338039df8466eee0a41ac57242b = L.circleMarker(
#                 [41.3954877, 2.1771985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9d6244d71113293c01870e3978764409);
#
#
#         var popup_8a0ed23f68d7baa07d6a547a0adc38fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ae7edecb23bc7adef2d35a97daf32fef = $(`&lt;div id=&quot;html_ae7edecb23bc7adef2d35a97daf32fef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;/div&gt;`)[0];
#                 popup_8a0ed23f68d7baa07d6a547a0adc38fc.setContent(html_ae7edecb23bc7adef2d35a97daf32fef);
#
#
#
#         circle_marker_74643338039df8466eee0a41ac57242b.bindPopup(popup_8a0ed23f68d7baa07d6a547a0adc38fc)
#         ;
#
#
#
#
#             var circle_marker_c8fb1c9a160f4439847182b97954ad32 = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9d6244d71113293c01870e3978764409);
#
#
#         var popup_b0f098ce3ec17f91806f39dbce7fd3c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6efefb56995ac7ba71e66bfb45457c58 = $(`&lt;div id=&quot;html_6efefb56995ac7ba71e66bfb45457c58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;/div&gt;`)[0];
#                 popup_b0f098ce3ec17f91806f39dbce7fd3c2.setContent(html_6efefb56995ac7ba71e66bfb45457c58);
#
#
#
#         circle_marker_c8fb1c9a160f4439847182b97954ad32.bindPopup(popup_b0f098ce3ec17f91806f39dbce7fd3c2)
#         ;
#
#
#
#
#             var circle_marker_6083e21c421f20a7f29a8355e3e11e3a = L.circleMarker(
#                 [41.3933173, 2.1812483],
#                 {&quot;bubblingMouseEvent

# %% [markdown]
# Luego de verificar que el mapa funciona, voy a tomar los datos de 2023, que es el ano mas actual que tengo. Para realizar un analisis en este ano.

# %% [markdown]
# ### Voy a filtar solo por el ano 2023

# %%
result_df_2023 = result_df[result_df['year']==2023]
result_df_2023['station_id'] = result_df_2023['station_id'].astype(int)

result_df_2023.head()
# Out:
# <ipython-input-26-67b5865d3946>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df_2023['station_id'] = result_df_2023['station_id'].astype(int)
#       station_id  year  month  day  hour  percentage_docks_available  \
# 4995           1  2023      1    1   2.0                    0.161111
# 4996           1  2023      1    1   7.0                    0.146296
# 4997           1  2023      1    1  12.0                    0.198148
# 4998           1  2023      1    1  17.0                    0.364815
# 4999           1  2023      1    1  22.0                    0.548148
#
#          ctx-4     ctx-3     ctx-2     ctx-1  weekday  is_weekend  is_festive
# 4995  0.177778  0.185185  0.187037  0.148148        6        True       False
# 4996  0.138889  0.146296  0.129630  0.153704        6        True       False
# 4997  0.190741  0.222222  0.209259  0.200000        6        True       False
# 4998  0.200000  0.300000  0.307407  0.342593        6        True       False
# 4999  0.394444  0.283333  0.224074  0.294444        6        True       False

# %% [markdown]
# ### Filtre los datos con Muelles Disponibles por debajo del 20% para **días entre semana (Lunes a viernes) y NO festivos** .
#
# Guarde las estaciones con ese indicador.

# %%
station_ids_weekday_nofestive = result_df_2023[(result_df_2023['is_festive'] == False) & (result_df_2023['is_weekend'] == False) & (result_df_2023['percentage_docks_available'] < 0.2)]['station_id'].values

# %%
import numpy as np

station_ids_weekday_nofestive = list(np.unique(station_ids_weekday_nofestive))

# %%
len(station_ids_weekday_nofestive)
# Out:
# 399

# %% [markdown]
# ### Filtre los datos con muelles disponibles por debajo del 20% para **días en fin de semana (Sabados y Domingos) o festivos** .
#
# Guarde las estaciones con ese indicador.

# %%
station_ids_weekend_festive = result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['percentage_docks_available'] < 0.2)]

# %%
import numpy as np

station_ids_weekend_festive = list(np.unique(station_ids_weekend_festive))

# %%
len(station_ids_weekday_nofestive)
# Out:
# 399

# %% [markdown]
# Identifico que todas las estaciones (399) están alguna vez en esta situación, seguramente por la recolocación de bicicletas.

# %% [markdown]
# ### Voy a probar otros filtros por ejemplo por horas.

# %%
station_ids_weekday_nofestive = list(np.unique(result_df_2023[(result_df_2023['is_festive'] == False) & (result_df_2023['is_weekend'] == False) & (result_df_2023['hour'] > 8) & (result_df_2023['hour'] < 10) & (result_df_2023['percentage_docks_available'] == 0.0)]['station_id'].values))
len(station_ids_weekday_nofestive)
# Out:
# 45

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids = set(station_ids_weekday_nofestive)

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekday_nofestive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f0d2c20bcabe81bffd7263ebf3a9b5c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f0d2c20bcabe81bffd7263ebf3a9b5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f0d2c20bcabe81bffd7263ebf3a9b5c = L.map(
#                 &quot;map_4f0d2c20bcabe81bffd7263ebf3a9b5c&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3cda32e57491e37b05db70908139ed1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4f0d2c20bcabe81bffd7263ebf3a9b5c);
#
#
#             var circle_marker_06fa1b859809d505397848b4b0ceb22e = L.circleMarker(
#                 [41.3833653, 2.1946255],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4f0d2c20bcabe81bffd7263ebf3a9b5c);
#
#
#         var popup_f0f9541e927aa28df8cf6b69eb9b0833 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_405549d461046c153fc6c32a7a7f9487 = $(`&lt;div id=&quot;html_405549d461046c153fc6c32a7a7f9487&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 12&lt;/div&gt;`)[0];
#                 popup_f0f9541e927aa28df8cf6b69eb9b0833.setContent(html_405549d461046c153fc6c32a7a7f9487);
#
#
#
#         circle_marker_06fa1b859809d505397848b4b0ceb22e.bindPopup(popup_f0f9541e927aa28df8cf6b69eb9b0833)
#         ;
#
#
#
#
#             var circle_marker_2ea5bf77da1062d6a59046b8dbb20bed = L.circleMarker(
#                 [41.3924661, 2.1717397],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4f0d2c20bcabe81bffd7263ebf3a9b5c);
#
#
#         var popup_e263dca875fc3c49b17a47df4fc9880c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2fd767855c3e5c6280511087c57fbd2 = $(`&lt;div id=&quot;html_e2fd767855c3e5c6280511087c57fbd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8010&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 23&lt;/div&gt;`)[0];
#                 popup_e263dca875fc3c49b17a47df4fc9880c.setContent(html_e2fd767855c3e5c6280511087c57fbd2);
#
#
#
#         circle_marker_2ea5bf77da1062d6a59046b8dbb20bed.bindPopup(popup_e263dca875fc3c49b17a47df4fc9880c)
#         ;
#
#
#
#
#             var circle_marker_e1372a9b8ea5a92391437a6edf8e579e = L.circleMarker(
#                 [41.4134833, 2.2206913],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4f0d2c20bcabe81bffd7263ebf3a9b5c);
#
#
#         var popup_3215d0702fdee55d298d96a04db57a5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f08dbc1dde59b3b5f683e2e3cade5ef = $(`&lt;div id=&quot;html_7f08dbc1dde59b3b5f683e2e3cade5ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8930&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 35&lt;/div&gt;`)[0];
#                 popup_3215d0702fdee55d298d96a04db57a5e.setContent(html_7f08dbc1dde59b3b5f683e2e3cade5ef);
#
#
#
#         circle_marker_e1372a9b8ea5a92391437a6edf8e579e.bindPopup(popup_3215d0702fdee55d298d96a04db57a5e)
#         ;
#
#
#
#
#             var circle_marker_d76839453f31171f9d21672411e155e9 = L.circleMarker(
#                 [41.3850616, 2.176

# %% [markdown]
# ## Analisis del filtro por horas : Con el codigo anterior podemos localizar las estaciones que se encuentran llenas a primera hora de la mañana en dias laborables, seguramente coincidiendo con puntos de gran afluencia de empresas.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 8) & (result_df_2023['hour'] < 10) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 17

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids = set(station_ids_weekend_festive) & union_ids
union_ids
# Out:
# {57, 124, 286}

# %% [markdown]
# Estas 3 estaciones tiene problemas de disponibilidad de huecos entre las 8 y las 10, independientemente de si es fin de semana o festivo o no.

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c720f1a7bb13b242cff139229288c7bd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c720f1a7bb13b242cff139229288c7bd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c720f1a7bb13b242cff139229288c7bd = L.map(
#                 &quot;map_c720f1a7bb13b242cff139229288c7bd&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc6aa233d7a452a6853efbd0752db22e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c720f1a7bb13b242cff139229288c7bd);
#
#
#             var circle_marker_a86ca3c701e5819863e6db675691f56e = L.circleMarker(
#                 [41.384844, 2.185085],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c720f1a7bb13b242cff139229288c7bd);
#
#
#         var popup_3ad058aee9d75f160e297a7dc3faf17a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23f4a782cd2d9b917044cff7e06a290e = $(`&lt;div id=&quot;html_23f4a782cd2d9b917044cff7e06a290e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 14&lt;/div&gt;`)[0];
#                 popup_3ad058aee9d75f160e297a7dc3faf17a.setContent(html_23f4a782cd2d9b917044cff7e06a290e);
#
#
#
#         circle_marker_a86ca3c701e5819863e6db675691f56e.bindPopup(popup_3ad058aee9d75f160e297a7dc3faf17a)
#         ;
#
#
#
#
#             var circle_marker_768b1f2ce67ff4f58342f6a537c0ca62 = L.circleMarker(
#                 [41.385086, 2.174016],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c720f1a7bb13b242cff139229288c7bd);
#
#
#         var popup_936b9bd4f8b664f2e7e1afb8a0d06676 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2e267694f910ec88b7264fca413d9350 = $(`&lt;div id=&quot;html_2e267694f910ec88b7264fca413d9350&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8002&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 53&lt;/div&gt;`)[0];
#                 popup_936b9bd4f8b664f2e7e1afb8a0d06676.setContent(html_2e267694f910ec88b7264fca413d9350);
#
#
#
#         circle_marker_768b1f2ce67ff4f58342f6a537c0ca62.bindPopup(popup_936b9bd4f8b664f2e7e1afb8a0d06676)
#         ;
#
#
#
#
#             var circle_marker_2637906eb24fe9cfa67329cc3ad86625 = L.circleMarker(
#                 [41.377187, 2.176757],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c720f1a7bb13b242cff139229288c7bd);
#
#
#         var popup_f9bde7137dac489b3f6bc79a581fd8d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3cb09f777ebfcea47bc1a2e82e8fee34 = $(`&lt;div id=&quot;html_3cb09f777ebfcea47bc1a2e82e8fee34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8002&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 57&lt;/div&gt;`)[0];
#                 popup_f9bde7137dac489b3f6bc79a581fd8d4.setContent(html_3cb09f777ebfcea47bc1a2e82e8fee34);
#
#
#
#         circle_marker_2637906eb24fe9cfa67329cc3ad86625.bindPopup(popup_f9bde7137dac489b3f6bc79a581fd8d4)
#         ;
#
#
#
#
#             var circle_marker_aa4267cd786f387d91bfba6cf80fe59f = L.circleMarker(
#                 [41.387696, 2.1696543],

# %% [markdown]
# Hay 17 estaciones que en fin de semana o Festivos, tienen las estaciones llenas de bicicletas, sin muelles disponibles, en algun momento entre las 8h00 and 10h00.
#
# Por tanto, considero que no es tan problemático este momento.
#
# Sin embargo, puedo buscar otros escenarios más interesantes para estas fechas.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 12) & (result_df_2023['hour'] < 18) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 70

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids2 = set(station_ids_weekend_festive)

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c40a4bfdc7d2c53744f3c2171d1af072 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c40a4bfdc7d2c53744f3c2171d1af072&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c40a4bfdc7d2c53744f3c2171d1af072 = L.map(
#                 &quot;map_c40a4bfdc7d2c53744f3c2171d1af072&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ecb15abcdd254e0592754700df42c5bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c40a4bfdc7d2c53744f3c2171d1af072);
#
#
#             var circle_marker_b7b26da158d9fd5395e7c3d52a87729b = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c40a4bfdc7d2c53744f3c2171d1af072);
#
#
#         var popup_1fa0b26e2568dc635505ff32046b0077 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7ddaeb68ab35f6c89189543348eb6021 = $(`&lt;div id=&quot;html_7ddaeb68ab35f6c89189543348eb6021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 3&lt;/div&gt;`)[0];
#                 popup_1fa0b26e2568dc635505ff32046b0077.setContent(html_7ddaeb68ab35f6c89189543348eb6021);
#
#
#
#         circle_marker_b7b26da158d9fd5395e7c3d52a87729b.bindPopup(popup_1fa0b26e2568dc635505ff32046b0077)
#         ;
#
#
#
#
#             var circle_marker_75473c838c1cc250c579ce0e25f3a114 = L.circleMarker(
#                 [41.384546, 2.184922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c40a4bfdc7d2c53744f3c2171d1af072);
#
#
#         var popup_0d5db9a1602dd4ca36a28994ca5de147 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8851ff888295502efc7b0e865f2e6077 = $(`&lt;div id=&quot;html_8851ff888295502efc7b0e865f2e6077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 9&lt;/div&gt;`)[0];
#                 popup_0d5db9a1602dd4ca36a28994ca5de147.setContent(html_8851ff888295502efc7b0e865f2e6077);
#
#
#
#         circle_marker_75473c838c1cc250c579ce0e25f3a114.bindPopup(popup_0d5db9a1602dd4ca36a28994ca5de147)
#         ;
#
#
#
#
#             var circle_marker_eb0868021784ea0851e49595924e0a8b = L.circleMarker(
#                 [41.388143, 2.195551],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c40a4bfdc7d2c53744f3c2171d1af072);
#
#
#         var popup_354c8eed1430f5d984ee52cb3e470b68 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6cc27e17277695c7444a5eacc9e9011 = $(`&lt;div id=&quot;html_d6cc27e17277695c7444a5eacc9e9011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8005&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 13&lt;/div&gt;`)[0];
#                 popup_354c8eed1430f5d984ee52cb3e470b68.setContent(html_d6cc27e17277695c7444a5eacc9e9011);
#
#
#
#         circle_marker_eb0868021784ea0851e49595924e0a8b.bindPopup(popup_354c8eed1430f5d984ee52cb3e470b68)
#         ;
#
#
#
#
#             var circle_marker_fe0c9ccff5ba86c1203163a73b23463b = L.circleMarker(
#                 [41.384844, 2.185085],

# %% [markdown]
# Por ejemplo, es interesante ver cómo los días festivos y fines de semanas, las estaciones pegadas al paseo marítimo y al borde de la playa están llenas en algún momento entre las 12h00 y las 18h00 del día, coincidiendo con las horas donde todavia hay claridad (es de dia) para aprovechar la playa.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 19) & (result_df_2023['hour'] < 23) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 46

# %%
# Guarde tambien los Station_ids "Comunes" a todos los casos

union_ids2 = set(station_ids_weekend_festive) & union_ids2
union_ids2
# Out:
# {9,
#  55,
#  57,
#  88,
#  104,
#  117,
#  133,
#  147,
#  157,
#  158,
#  171,
#  176,
#  178,
#  179,
#  260,
#  269,
#  279,
#  284,
#  340,
#  348,
#  361,
#  389,
#  392,
#  402,
#  425}

# %% [markdown]
# Y esta lista de estaciones tiene problemas con muelles disponibles entre las 12 y las 6 y entre las 7 y las 23 durante festivos y fines de semana por lo que habría que reforzarlas.

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99088999b8cf5d273a723f256382b24b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99088999b8cf5d273a723f256382b24b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99088999b8cf5d273a723f256382b24b = L.map(
#                 &quot;map_99088999b8cf5d273a723f256382b24b&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c0ef3af2f29a08a22d7f6db1803c53c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_99088999b8cf5d273a723f256382b24b);
#
#
#             var circle_marker_074db82b2b3d0efca6e4b57d6c41a1d5 = L.circleMarker(
#                 [41.384546, 2.184922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_99088999b8cf5d273a723f256382b24b);
#
#
#         var popup_613199e1d2aa3b8196b72aee059dca57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f99cd1eb56dbccd944d686661c3bc44 = $(`&lt;div id=&quot;html_3f99cd1eb56dbccd944d686661c3bc44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 9&lt;/div&gt;`)[0];
#                 popup_613199e1d2aa3b8196b72aee059dca57.setContent(html_3f99cd1eb56dbccd944d686661c3bc44);
#
#
#
#         circle_marker_074db82b2b3d0efca6e4b57d6c41a1d5.bindPopup(popup_613199e1d2aa3b8196b72aee059dca57)
#         ;
#
#
#
#
#             var circle_marker_e797e0be46f11b11ee4992de74c0ff53 = L.circleMarker(
#                 [41.3812425, 2.1933482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_99088999b8cf5d273a723f256382b24b);
#
#
#         var popup_6a072e75ec57bff013c233e681db6316 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_215a980ad401e2659ffbb360f6e2e0fd = $(`&lt;div id=&quot;html_215a980ad401e2659ffbb360f6e2e0fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 11&lt;/div&gt;`)[0];
#                 popup_6a072e75ec57bff013c233e681db6316.setContent(html_215a980ad401e2659ffbb360f6e2e0fd);
#
#
#
#         circle_marker_e797e0be46f11b11ee4992de74c0ff53.bindPopup(popup_6a072e75ec57bff013c233e681db6316)
#         ;
#
#
#
#
#             var circle_marker_66c3b624c65c6d9b2fb86ed47e339f43 = L.circleMarker(
#                 [41.3775319, 2.1707321],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_99088999b8cf5d273a723f256382b24b);
#
#
#         var popup_46d0dd8e371402d109d959468a2f2dc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b2c5a40791aa6104d05f03568e7272f = $(`&lt;div id=&quot;html_7b2c5a40791aa6104d05f03568e7272f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8001&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 54&lt;/div&gt;`)[0];
#                 popup_46d0dd8e371402d109d959468a2f2dc0.setContent(html_7b2c5a40791aa6104d05f03568e7272f);
#
#
#
#         circle_marker_66c3b624c65c6d9b2fb86ed47e339f43.bindPopup(popup_46d0dd8e371402d109d959468a2f2dc0)
#         ;
#
#
#
#
#             var circle_marker_a2b3a3bdd86edea49668e72893a89f73 = L.circleMarker(
#                 [41.3811923, 2.173500

# %% [markdown]
# No ocurre lo mismo entre las 19 y las 23h, donde las estaciones del centro parece estar saturadas.

# %% [markdown]
# Todos estos datos me sirven para verificar/identificar estaciones que se colapsan y habría que ampliar de tamaño o llenar/vaciar de bicicletas con más frecuencia en ciertos tramos horarios.

# %%
station_ids_weekend_festive = list(np.unique(result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 12) & (result_df_2023['hour'] < 23) & (result_df_2023['percentage_docks_available'] == 0)]['station_id'].values))
len(station_ids_weekend_festive)
# Out:
# 101

# %%
df_filtered = df_info[df_info['station_id'].isin(station_ids_weekend_festive)]

# %%
lats = df_filtered['lat'][:]
lons = df_filtered['lon'][:]
post_codes = df_filtered['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = [1] * len(lats)
ids = df_filtered['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=2,
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57bd7e94cc193fc0ffb436e8f628d6e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57bd7e94cc193fc0ffb436e8f628d6e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57bd7e94cc193fc0ffb436e8f628d6e7 = L.map(
#                 &quot;map_57bd7e94cc193fc0ffb436e8f628d6e7&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc6e2d820186f70157cb40b28ca04bb5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57bd7e94cc193fc0ffb436e8f628d6e7);
#
#
#             var circle_marker_4b28875253eeafbf19a8d97505629196 = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_57bd7e94cc193fc0ffb436e8f628d6e7);
#
#
#         var popup_28b2b9890d08577465f5f22b390222e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17415c975aac5ec0a8809c56bf088476 = $(`&lt;div id=&quot;html_17415c975aac5ec0a8809c56bf088476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 3&lt;/div&gt;`)[0];
#                 popup_28b2b9890d08577465f5f22b390222e5.setContent(html_17415c975aac5ec0a8809c56bf088476);
#
#
#
#         circle_marker_4b28875253eeafbf19a8d97505629196.bindPopup(popup_28b2b9890d08577465f5f22b390222e5)
#         ;
#
#
#
#
#             var circle_marker_95acd92fac6cb637c9838c63b9a5897d = L.circleMarker(
#                 [41.384546, 2.184922],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_57bd7e94cc193fc0ffb436e8f628d6e7);
#
#
#         var popup_6d8df3ffa76d7d51d46604d50dc74391 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea67e8ca127fded9d588f4ab43f54cbd = $(`&lt;div id=&quot;html_ea67e8ca127fded9d588f4ab43f54cbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 9&lt;/div&gt;`)[0];
#                 popup_6d8df3ffa76d7d51d46604d50dc74391.setContent(html_ea67e8ca127fded9d588f4ab43f54cbd);
#
#
#
#         circle_marker_95acd92fac6cb637c9838c63b9a5897d.bindPopup(popup_6d8df3ffa76d7d51d46604d50dc74391)
#         ;
#
#
#
#
#             var circle_marker_3fa3414ac6c5e299ba015fb7c9e45539 = L.circleMarker(
#                 [41.3812425, 2.1933482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_57bd7e94cc193fc0ffb436e8f628d6e7);
#
#
#         var popup_257a9e30c73401e9f19c163b53b41569 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_808f9ade49f1eae7156ddfae56000c07 = $(`&lt;div id=&quot;html_808f9ade49f1eae7156ddfae56000c07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8003&lt;br&gt;City: Barcelona&lt;br&gt;Value: 1&lt;br&gt;Id: 11&lt;/div&gt;`)[0];
#                 popup_257a9e30c73401e9f19c163b53b41569.setContent(html_808f9ade49f1eae7156ddfae56000c07);
#
#
#
#         circle_marker_3fa3414ac6c5e299ba015fb7c9e45539.bindPopup(popup_257a9e30c73401e9f19c163b53b41569)
#         ;
#
#
#
#
#             var circle_marker_fb903cadc7eb7488f5ef5d706a674b9f = L.circleMarker(
#                 [41.388143, 2.195551],

# %% [markdown]
# Por ultimo, voy a mostrar las estaciones llenas en festivos y fines de semana entre las 12 y las 23, mostrando lugares desde donde más gente toma bicicletas para desplazarse en el fin de semana, por lo que serían éstas estaciones las que habría que llenar con las bicicletas obtenidas anteriormente de las estaciones saturadas por el centro o la playa.

# %% [markdown]
# ## Analisis mapa con información del porcentaje de muelles disponibles

# %% [markdown]
# Primero filtre los datos por festivos o fin de semana y en el horario entre las 12 y las 18.
#
# Después saque/identifique/genere la media del valor de la proporción de muelles disponibles en ese tramo horario para cada estación.

# %%
result_df_2023_filtered = result_df_2023[((result_df_2023['is_festive'] == True) | (result_df_2023['is_weekend'] == True)) & (result_df_2023['hour'] > 12) & (result_df_2023['hour'] < 23)]
result_df_2023_filtered = result_df_2023_filtered[['station_id', 'percentage_docks_available']].groupby('station_id').mean()
result_df_2023_filtered = result_df_2023_filtered.reset_index()
result_df_2023_filtered
# Out:
#      station_id  percentage_docks_available
# 0             1                    0.769158
# 1             2                    0.663473
# 2             3                    0.499445
# 3             4                    0.496202
# 4             5                    0.635562
# ..          ...                         ...
# 394         474                    0.831421
# 395         492                    0.536327
# 396         494                    0.562992
# 397         495                    0.529004
# 398         496                    0.574929
#
# [399 rows x 2 columns]

# %% [markdown]
# Pege/integre la media de la proporción de muelles disponibles con la información de las estaciones para hacer el mapa.

# %%
df_filtered = df_info[df_info['station_id'].isin(list(result_df_2023_filtered['station_id'].values))]

# %%
df_merged = pd.merge(df_filtered, result_df_2023_filtered, on='station_id', how='left')

df_merged.head()
# Out:
#    station_id                                 name physical_configuration  \
# 0           1        GRAN VIA CORTS CATALANES, 760    ELECTRICBIKESTATION
# 1           2                C/ ROGER DE FLOR, 126    ELECTRICBIKESTATION
# 2           3                        C/ NÀPOLS, 82    ELECTRICBIKESTATION
# 3           4                         C/ RIBES, 13    ELECTRICBIKESTATION
# 4           5  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)    ELECTRICBIKESTATION
#
#          lat       lon  altitude                              address  \
# 0  41.397978  2.180107      16.0        GRAN VIA CORTS CATALANES, 760
# 1  41.395488  2.177198      17.0                C/ ROGER DE FLOR, 126
# 2  41.394156  2.181331      11.0                        C/ NÀPOLS, 82
# 3  41.393317  2.181248       8.0                         C/ RIBES, 13
# 4  41.391103  2.180176       7.0  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)
#
#    post_code  capacity  is_charging_station  nearby_distance  \
# 0       8013        45                 True           1000.0
# 1       8013        29                 True           1000.0
# 2       8013        27                 True           1000.0
# 3       8013        21                 True           1000.0
# 4       8018        39                 True           1000.0
#
#    _ride_code_support  rental_uris cross_street  percentage_docks_available
# 0                True          NaN          NaN                    0.769158
# 1                True          NaN          NaN                    0.663473
# 2                True          NaN          NaN                    0.499445
# 3                True          NaN          NaN                    0.496202
# 4                True          NaN          NaN                    0.635562

# %% [markdown]
# Contrui/hice el mapa con el tamaño de los círculos en función del Inverso del percetage_docks_available.
#
# 1-percetage_docks_available es la proporción de bicis disponibles en la estación.

# %%
lats = df_merged['lat'][:]
lons = df_merged['lon'][:]
post_codes = df_merged['post_code'][:]
cities = ['Barcelona'] * len(lats)
values = 10*(1-df_merged['percentage_docks_available'][:])
ids = df_merged['station_id'][:]

# Step 1: Create synthetic data for postal codes
data = {
    'postal_code': post_codes,
    'city': cities,
    'value': values,
    'latitude': lats,
    'longitude': lons,
    'ids': ids
}

df = pd.DataFrame(data)

# Step 2: Create a folium map centered around Barcelona
m = folium.Map(location=[41.39, 2.18], zoom_start=12)

# Step 3: Add markers to the map for each postal code
for _, row in df.iterrows():
    folium.CircleMarker(
        location=(row['latitude'], row['longitude']),
        radius=row['value'],
        color='blue',
        fill=True,
        fill_color='blue',
        popup=f"Postal Code: {row['postal_code']}<br>City: {row['city']}<br>Value: {row['value']}<br>Id: {row['ids']}"
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_afe9b37564d7f170113555a9124e0404 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_afe9b37564d7f170113555a9124e0404&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_afe9b37564d7f170113555a9124e0404 = L.map(
#                 &quot;map_afe9b37564d7f170113555a9124e0404&quot;,
#                 {
#                     center: [41.39, 2.18],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96b1aa741048ac852362bc26ee72c681 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_afe9b37564d7f170113555a9124e0404);
#
#
#             var circle_marker_2e22ea6bee13824fd76f1fdec5a8105c = L.circleMarker(
#                 [41.3979779, 2.1801069],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.3084151801224975, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_afe9b37564d7f170113555a9124e0404);
#
#
#         var popup_10acfa50d45fbb89bdc3f4db726c192e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_289434403aac27eceef77c99ec0f6312 = $(`&lt;div id=&quot;html_289434403aac27eceef77c99ec0f6312&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 2.3084151801224975&lt;br&gt;Id: 1&lt;/div&gt;`)[0];
#                 popup_10acfa50d45fbb89bdc3f4db726c192e.setContent(html_289434403aac27eceef77c99ec0f6312);
#
#
#
#         circle_marker_2e22ea6bee13824fd76f1fdec5a8105c.bindPopup(popup_10acfa50d45fbb89bdc3f4db726c192e)
#         ;
#
#
#
#
#             var circle_marker_39a7828ea7b751a60b0aa7089052d53d = L.circleMarker(
#                 [41.3954877, 2.1771985],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.3652733056891284, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_afe9b37564d7f170113555a9124e0404);
#
#
#         var popup_3bd544274b7631cba62c659711564a43 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2930def0f3d86a2181d1917861d5c4d5 = $(`&lt;div id=&quot;html_2930def0f3d86a2181d1917861d5c4d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 3.3652733056891284&lt;br&gt;Id: 2&lt;/div&gt;`)[0];
#                 popup_3bd544274b7631cba62c659711564a43.setContent(html_2930def0f3d86a2181d1917861d5c4d5);
#
#
#
#         circle_marker_39a7828ea7b751a60b0aa7089052d53d.bindPopup(popup_3bd544274b7631cba62c659711564a43)
#         ;
#
#
#
#
#             var circle_marker_84ed444611666c0981cd6dcad91acba7 = L.circleMarker(
#                 [41.3941557, 2.1813305],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.005554923847607, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_afe9b37564d7f170113555a9124e0404);
#
#
#         var popup_569e58a64e5f20f0f0b3d6d654f35142 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_89c61b934d1ef110741ca7b8b9635801 = $(`&lt;div id=&quot;html_89c61b934d1ef110741ca7b8b9635801&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Postal Code: 8013&lt;br&gt;City: Barcelona&lt;br&gt;Value: 5.005554923847607&lt;br&gt;Id: 3&lt;/div&gt;`)[0];
#                 popup_569e58a64e5f20f0f0b3d6d654f35142.setContent(html_89c61b934d1ef110741ca7b8b9635801);
#
#
#
#         circle_marker_84ed444611666c0981cd6dcad91acba7.bindPopup(popup_569e58a64e5f20f0f0b3d6d654f35142)
#         ;
#
#
#
#
#             var ci

# %% [markdown]
# Este último mapa muestra las estaciones según el nivel de saturación durante el día (12-23) de días festivos y fines de semanas.
#
# Las estaciones con más saturación tienen círculos más grandes, es decir, aquellas que tienen más bicicletas según capacidad y por tanto menos muelles disponibles.
#
#
# Claramente se ven las estaciones del centro y playa más saturadas que el resto de estaciones.

# %% [markdown]
# Mariona y Pere, si hacen click en alguna estación del mapa podran obtener/observar/analizar la información sobre esa estación como el Station_id o la proporción de bicicletas disponibles.
