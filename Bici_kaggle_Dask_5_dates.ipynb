# %% [markdown]
# <a href="https://colab.research.google.com/github/jafuma0320/2024-Online-Bike-Availability-Prediction/blob/Feature%2Fadd-file/Bici_kaggle_Dask_5_dates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install py7zr

# %%
import os
import py7zr

i2m = list(zip(range(1,13), ['Gener','Febrer','Marc','Abril','Maig','Juny','Juliol','Agost','Setembre','Octubre','Novembre','Desembre']))
for year in [2023, 2022, 2021, 2020]:
    for month, month_name in i2m:
        os.system(f"wget 'https://opendata-ajuntament.barcelona.cat/resources/bcn/BicingBCN/{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")
        os.system(f"7z x '{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")

        archive = py7zr.SevenZipFile(f'{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z', mode='r')
        archive.extractall(path="/content/drive/MyDrive/BiciKaggle/tmp")
        archive.close()

        os.system(f"rm '{year}_{month:02d}_{month_name}_BicingNou_ESTACIONS.7z'")

# %%
import pandas as pd

# %%
# Desmontar cualquier montaje existente (si lo hay)
# !fusermount -u /content/drive

# Eliminar el directorio y recrearlo
# !rm -rf /content/drive
# !mkdir -p /content/drive

# Montar Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Lectura de los datos

# %%
filepath_info = '/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/Informacio_Estacions_Bicing.csv'

# %%
df = pd.read_csv(filepath_info, sep=',')
df
# Out:
#      station_id                                 name physical_configuration  \
# 0             1        GRAN VIA CORTS CATALANES, 760    ELECTRICBIKESTATION
# 1             2                C/ ROGER DE FLOR, 126    ELECTRICBIKESTATION
# 2             3                        C/ NÀPOLS, 82    ELECTRICBIKESTATION
# 3             4                         C/ RIBES, 13    ELECTRICBIKESTATION
# 4             5  PG. LLUIS COMPANYS, 11 (ARC TRIOMF)    ELECTRICBIKESTATION
# ..          ...                                  ...                    ...
# 501         515                    C/ SANT ADRIÀ, 43    ELECTRICBIKESTATION
# 502         516                    C/ SANT ADRIÀ, 88    ELECTRICBIKESTATION
# 503         517             AV. RASOS DE PEGUERA, 10    ELECTRICBIKESTATION
# 504         518                    C/ LLOBREGÓS, 115    ELECTRICBIKESTATION
# 505         519                       C/ PEDRELL, 52    ELECTRICBIKESTATION
#
# ...

# %%
filepath_metadata = '/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/metadata_sample_submission_2024.csv'
df_metadata = pd.read_csv(filepath_metadata, sep=',')
df_metadata
# Out:
#          index  station_id  month  day  hour     ctx-4     ctx-3     ctx-2  \
# 0            0           1      1    1     5  0.781481  0.677778  0.696296
# 1            1           1      1    1    10  0.737374  0.711111  0.711111
# 2            2           1      1    1    15  0.827778  0.896296  0.901852
# 3            3           1      1    1    20  0.825926  0.874074  0.927778
# 4            4           2      1    1     3  0.592593  0.341954  0.275862
# ...        ...         ...    ...  ...   ...       ...       ...       ...
# 171897  171897         496      3   31     1  0.828704  0.787037  0.777778
# 171898  171898         496      3   31     6  0.930556  0.944444  0.935185
# 171899  171899         496      3   31    11  0.912037  0.884259  0.518519
# 171900  171900         496      3   31    16  0.245370  0.319444  0.277778
# 171901  171901         496      3   31    21  0.513889  0.435185  0.490741
#
#            ctx-1
# 0       0.750000
# 1       0.731624
# ...

# %%
filepath_submission = '/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/sample_submission_2024.csv'
df_submission = pd.read_csv(filepath_submission, sep=',')
df_submission
# Out:
#          index  percentage_docks_available
# 0            0                    0.228074
# 1            1                    0.776294
# 2            2                    0.485480
# 3            3                    0.405185
# 4            4                    0.773393
# ...        ...                         ...
# 171897  171897                    0.870746
# 171898  171898                    0.874182
# 171899  171899                    0.284646
# 171900  171900                    0.684282
# 171901  171901                    0.299685
#
# [171902 rows x 2 columns]

# %%
filepath_example = '/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/Dask/tmp/2020_01_Gener_BicingNou_ESTACIONS.csv'
df_example = pd.read_csv(filepath_example, sep=',')
df_example
# Out:
#          station_id  num_bikes_available  \
# 0                 1                   21
# 1                 2                   10
# 2                 3                   15
# 3                 4                    8
# 4                 5                   14
# ...             ...                  ...
# 3398703         474                    7
# 3398704         492                    2
# 3398705         494                    0
# 3398706         495                    3
# 3398707         496                   15
#
#          num_bikes_available_types.mechanical  \
# 0                                          21
# 1                                           9
# 2                                          15
# 3                                           8
# 4                                          11
# ...                                       ...
# 3398703                                     5
# 3398704                                     2
# ...

# %%
import os
# Define the folder path
folder_path = '/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/Dask/tmp'

# List all CSV files in the directory
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]
csv_files
# Out:
# ['2023_12_Desembre_BicingNou_ESTACIONS.csv',
#  '2023_11_Novembre_BicingNou_ESTACIONS.csv',
#  '2023_10_Octubre_BicingNou_ESTACIONS.csv',
#  '2023_09_Setembre_BicingNou_ESTACIONS.csv',
#  '2023_08_Agost_BicingNou_ESTACIONS.csv',
#  '2023_07_Juliol_BicingNou_ESTACIONS.csv',
#  '2023_06_Juny_BicingNou_ESTACIONS.csv',
#  '2023_05_Maig_BicingNou_ESTACIONS.csv',
#  '2023_04_Abril_BicingNou_ESTACIONS.csv',
#  '2023_03_Marc_BicingNou_ESTACIONS.csv',
#  '2023_02_Febrer_BicingNou_ESTACIONS.csv',
#  '2023_01_Gener_BicingNou_ESTACIONS.csv',
#  '2022_12_Desembre_BicingNou_ESTACIONS.csv',
#  '2022_11_Novembre_BicingNou_ESTACIONS.csv',
#  '2022_10_Octubre_BicingNou_ESTACIONS.csv',
#  '2022_09_Setembre_BicingNou_ESTACIONS.csv',
#  '2022_08_Agost_BicingNou_ESTACIONS.csv',
#  '2022_07_Juliol_BicingNou_ESTACIONS.csv',
#  '2022_06_Juny_BicingNou_ESTACIONS.csv',
#  '2022_05_Maig_BicingNou_ESTACIONS.csv',
#  '2022_04_Abril_BicingNou_ESTACIONS.csv',
#  '2022_03_Març_BicingNou_ESTACIONS.csv',
# ...

# %%
# Dictionary to store DataFrames
dataframes = {}

# Loop through the CSV files and read each one into a DataFrame
for file in csv_files:    # Bucle que recorre todos los archivos csv
    file_path = os.path.join(folder_path, file)   # Define la ubicación del archivo csv uniendo el nombre del archivo con el path (directorio actual, ./)
    df = pd.read_csv(file_path, sep=',')          # Leer en un dataframe (tipo de datos de la librería pandas) el archivo csv que se está procesando en la iteración actual


    dataframes[file] = df
# Out:
# <ipython-input-16-674d37fdac1e>:7: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep=',')          # Leer en un dataframe (tipo de datos de la librería pandas) el archivo csv que se está procesando en la iteración actual
# <ipython-input-16-674d37fdac1e>:7: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, sep=',')          # Leer en un dataframe (tipo de datos de la librería pandas) el archivo csv que se está procesando en la iteración actual

# %%
all_data = pd.concat(dataframes.values(), ignore_index=True)
all_data.to_csv('all_data.csv', index=False)

# %% [markdown]
# Run from here after downloading and joining all files

# %%
import pandas as pd

all_data = pd.read_csv('/content/drive/MyDrive/University of Barcelona/Capstone_Project_2024/all_data.csv')

# %%
all_data.head()

# %%
all_data['status'].unique()

# %%
import dask.dataframe as dd

# %%
dask_df = dd.from_pandas(all_data, npartitions=100)

# %%
dask_df.dtypes

# %%
dask_df['date'] = dd.to_datetime(dask_df.last_reported, unit='s')
dask_df['month'] = dask_df['date'].dt.month
dask_df['day'] = dask_df['date'].dt.day
dask_df['year'] = dask_df['date'].dt.year
dask_df['hour'] = dask_df['date'].dt.hour

# %%
dask_df.dtypes

# %%
replace_map_status  = {'IN_SERVICE': 0, 'PLANNED':1,  'NOT_IN_SERVICE': 2, 'MAINTENANCE': 3, 'END_OF_LIFE': 4, '<NA>': -1}


# Replace the string values with numbers
dask_df['status_num'] = dask_df['status'].map_partitions(lambda x: x.astype('str').replace(replace_map_status )).astype('int64')

# %%
print(dask_df['status_num'].unique().compute())

# %%
replace_map_charging  = {'True': 1, 'False': 0, '<NA>': -1}

# Replace the string values with numbers
dask_df['is_charging_station_num'] = dask_df['is_charging_station'].map_partitions(lambda x: x.astype('str').replace(replace_map_charging)).astype('int64')

# %%
dask_df.dtypes

# %%
dask_df['status'].unique().compute()

# %%
dask_df['is_charging_station'].unique().compute()

# %%
dask_df['is_installed'].unique().compute()

# %%
dask_df['status_num'].unique().compute()

# %%
dask_df['is_charging_station_num'].unique().compute()

# %%
df_num = dask_df.drop(columns=['status', 'is_charging_station', 'date']).compute()

# %% [markdown]
# Obtención de la fecha y hora

# %%
# !pip install dask[dataframe]

# %%
import dask.dataframe as dd

# %%
df = dd.read_csv('tmp/*.csv', dtype={
    'station_id': 'int64',
    'num_bikes_available': 'int64',
    'num_bikes_available_types.mechanical': 'int64',
    'num_bikes_available_types.ebike': 'int64',
    'num_docks_available': 'int64',
    'is_installed': 'int64',
    'is_renting': 'int64',
    'is_returning': 'int64',
    'last_reported': 'float64',
    'is_charging_station': 'bool',
    'status': 'object',
    'last_updated': 'int64',
    'ttl': 'int64'
}, low_memory=False)

df.dtypes

# %%
df.head()

# %%
df.dtypes

# %%
df

# %%
# mean_docks_available_df = df.groupby(['station_id', 'year','month','day','hour'])['num_docks_available'].mean().reset_index()
# mean_docks_available_df.head()

# %%
# Drop unnecessary columns
df_num = df.drop(columns=['date'])

# Compute and display the head of the resulting DataFrame
df_num_computed = df_num.compute()
df_num_computed.head()

# %%
replace_map = {'IN_SERVICE': 1, 'CLOSED': 2}

# Replace the string values with numbers
df['status_num'] = df['status'].replace(replace_map).astype('float64')

# %%
replace_map = {True: 1, False: 0}

# Replace the string values with numbers
df['is_charging_station_num'] = df['is_charging_station'].replace(replace_map).astype('float64')

# %%
df

# %%
df_num = df[['station_id', 'num_bikes_available', 'num_bikes_available_types.mechanical', 'num_bikes_available_types.ebike', 'num_docks_available', 'is_installed', 'is_renting', 'is_returning', 'last_reported', 'is_charging_station_num', 'ttl', 'year', 'month', 'day', 'hour']].compute()
df_num.head()

# %%
df_num.dtypes

# %%
df_simplified = df[['station_id', 'num_docks_available', 'num_bikes_available', 'Year', 'Month', 'Day', 'Hour']]

# %%
df_simplified

# %%
df_simplified[df_simplified['station_id']==1][:20]

# %%
grouped_series = df_simplified.groupby(['station_id','Year', 'Month', 'Day', 'Hour']).mean()
grouped_series

# %%
grouped_series = grouped_series[['num_docks_available', 'num_bikes_available']]
grouped_series

# %%
grouped_series[:30]

# %%
grouped_series = grouped_series.reset_index()
grouped_series

# %%
grouped_series.columns

# %% [markdown]
# # Read all csv files

# %%
import os

# %%
# Define the folder path
folder_path = './'  # Replace with your folder path

# List all CSV files in the directory
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# %%
csv_files

# %%
# csv_files = [
#  '2021_10_Octubre_BicingNou_ESTACIONS.csv',
#  '2021_11_Novembre_BicingNou_ESTACIONS.csv',
#  '2021_12_Desembre_BicingNou_ESTACIONS.csv'
# ]

# %%
# Dictionary to store DataFrames
dataframes = {}

# Loop through the CSV files and read each one into a DataFrame
for file in csv_files:    # Bucle que recorre todos los archivos csv
    file_path = os.path.join(folder_path, file)   # Define la ubicación del archivo csv uniendo el nombre del archivo con el path (directorio actual, ./)
    df = pd.read_csv(file_path, sep=',')          # Leer en un dataframe (tipo de datos de la librería pandas) el archivo csv que se está procesando en la iteración actual

    df['Year'] = df['last_updated'].dropna().apply(compute_year)   # Añadimos columna con el año
    df['Month'] = df['last_updated'].dropna().apply(compute_month)
    df['Day'] = df['last_updated'].dropna().apply(compute_day)
    df['Hour'] = df['last_updated'].dropna().apply(compute_hour)

    df_simplified = df[['station_id', 'num_docks_available', 'num_bikes_available', 'Year', 'Month', 'Day', 'Hour']] # Eliminamos columnas que no vamos a usar

    grouped_series = df_simplified.groupby(['station_id','Year', 'Month', 'Day', 'Hour']).mean()    # Agrupamos por estación, año, mes, día y hora, y hcemos la media a los muelles disponibles en cada hora
    grouped_series = grouped_series[['num_docks_available', 'num_bikes_available']]
    grouped_series = grouped_series.reset_index()


    dataframes[file] = grouped_series

# %%
all_data = pd.concat(dataframes.values(), ignore_index=True)
all_data.to_csv('/content/drive/MyDrive/BiciKaggle/combined_data_2.csv', index=False)

# %%
df['Year'] = df['last_updated'].dropna().apply(compute_year)

# %%
df[['station_id', 'num_docks_available', 'Year']]

# %%
all_data.head()

# %%
all_data.info()
